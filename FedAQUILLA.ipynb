# %% [markdown]
# # Step-1:Data Collection

# %%
print("TOP OF FILE EXECUTED")
# Out:
# TOP OF FILE EXECUTED

# %%
# !pip install google-cloud-storage
# Out:
# Collecting google-cloud-storage
#   Downloading google_cloud_storage-3.9.0-py3-none-any.whl.metadata (15 kB)
# Collecting google-auth<3.0.0,>=2.26.1 (from google-cloud-storage)
#   Downloading google_auth-2.48.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting google-api-core<3.0.0,>=2.27.0 (from google-cloud-storage)
#   Downloading google_api_core-2.30.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-cloud-core<3.0.0,>=2.4.2 (from google-cloud-storage)
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage)
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from google-cloud-storage) (2.32.5)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage)
#   Downloading google_crc32c-1.8.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (1.7 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.3 (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (5.29.3)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage)
#   Downloading proto_plus-1.27.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /opt/anaconda3/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (46.0.3)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.26.1->google-cloud-storage)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.6.1)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (2.23)
# Downloading google_cloud_storage-3.9.0-py3-none-any.whl (321 kB)
# Downloading google_api_core-2.30.0-py3-none-any.whl (173 kB)
# Downloading google_auth-2.48.0-py3-none-any.whl (236 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.8.0-cp313-cp313-macosx_12_0_arm64.whl (31 kB)
# Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading proto_plus-1.27.1-py3-none-any.whl (50 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Installing collected packages: rsa, proto-plus, googleapis-common-protos, google-crc32c, google-resumable-media, google-auth, google-api-core, google-cloud-core, google-cloud-storage
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [google-cloud-storage]m 8/9 [google-cloud-storage]
# Successfully installed google-api-core-2.30.0 google-auth-2.48.0 google-cloud-core-2.5.0 google-cloud-storage-3.9.0 google-crc32c-1.8.0 google-resumable-media-2.8.0 googleapis-common-protos-1.72.0 proto-plus-1.27.1 rsa-4.9.1

# %% [markdown]
# ### Downloading data from google cloud storage

# %%
from google.cloud import storage
import os
from time import sleep

#  Create anonymous GCS client
client = storage.Client.create_anonymous_client()
bucket = client.bucket("clusterdata-2011-2")

#  Folder to save files locally
save_dir = r"D:\google_cluster_trace\task_usage"
os.makedirs(save_dir, exist_ok=True)

#  Loop over all 500 files
for i in range(500):
    blob_name = f"task_usage/part-{i:05d}-of-00500.csv.gz"
    dest_file = os.path.join(save_dir, os.path.basename(blob_name))
    blob = bucket.blob(blob_name)

    #  Skip already downloaded files
    if os.path.exists(dest_file):
        print(f" [{i+1:03d}/500] Already exists → {os.path.basename(dest_file)}")
        continue

    print(f"  [{i+1:03d}/500] Downloading → {os.path.basename(blob_name)}")
    try:
        blob.download_to_filename(dest_file)
        print(f" [{i+1:03d}/500] Download complete → {os.path.basename(dest_file)}")
    except Exception as e:
        print(f" [{i+1:03d}/500] Failed: {os.path.basename(blob_name)} | Error: {e}")
        sleep(2)

print("\n All downloads finished! Check folder:")
print(save_dir)
# Out:
#   [001/500] Downloading → part-00000-of-00500.csv.gz
#  [001/500] Download complete → part-00000-of-00500.csv.gz
#   [002/500] Downloading → part-00001-of-00500.csv.gz
#  [002/500] Download complete → part-00001-of-00500.csv.gz
#   [003/500] Downloading → part-00002-of-00500.csv.gz
#  [003/500] Download complete → part-00002-of-00500.csv.gz
#   [004/500] Downloading → part-00003-of-00500.csv.gz
#  [004/500] Download complete → part-00003-of-00500.csv.gz
#   [005/500] Downloading → part-00004-of-00500.csv.gz
#  [005/500] Download complete → part-00004-of-00500.csv.gz
#   [006/500] Downloading → part-00005-of-00500.csv.gz
#  [006/500] Download complete → part-00005-of-00500.csv.gz
#   [007/500] Downloading → part-00006-of-00500.csv.gz
#  [007/500] Download complete → part-00006-of-00500.csv.gz
#   [008/500] Downloading → part-00007-of-00500.csv.gz
#  [008/500] Download complete → part-00007-of-00500.csv.gz
#   [009/500] Downloading → part-00008-of-00500.csv.gz
#  [009/500] Download complete → part-00008-of-00500.csv.gz
print(f"Total files found: {len(files)}")

# -------------------------------
# 2️⃣ Merge Files (Chunk Based)
# -------------------------------

first = True  # Write header only once

for file_index, file in enumerate(files, start=1):
    
    print(f"[{file_index}/{len(files)}] Processing: {os.path.basename(file)}")
    
    # Read file in chunks to prevent memory overflow
    for chunk in pd.read_csv(
        file,
        compression='gzip',
        header=None,
        chunksize=500000
    ):
        
        # Keep only first 8 columns
        chunk = chunk.iloc[:, :8]
        
        # Remove completely empty rows (optional safety)
        chunk = chunk.dropna(how='all')
        
        # Append to output file
        chunk.to_csv(
            output_file,
            mode='a',
            index=False,
            header=first,
            compression='gzip'
        )
        
        first = False

print("\n✅ Merged dataset with first 8 columns created successfully.")
print(f"📁 Saved at: {output_file}")
# Out:
# Total files found: 499
# [1/499] Processing: part-00001-of-00500.csv.gz
# [2/499] Processing: part-00002-of-00500.csv.gz
# [3/499] Processing: part-00003-of-00500.csv.gz
# [4/499] Processing: part-00004-of-00500.csv.gz
# [5/499] Processing: part-00005-of-00500.csv.gz
# [6/499] Processing: part-00006-of-00500.csv.gz
# [7/499] Processing: part-00007-of-00500.csv.gz
# [8/499] Processing: part-00008-of-00500.csv.gz
# [9/499] Processing: part-00009-of-00500.csv.gz
# [10/499] Processing: part-00010-of-00500.csv.gz
# [11/499] Processing: part-00011-of-00500.csv.gz
# [12/499] Processing: part-00012-of-00500.csv.gz
# [13/499] Processing: part-00013-of-00500.csv.gz
# [14/499] Processing: part-00014-of-00500.csv.gz
# [15/499] Processing: part-00015-of-00500.csv.gz
# [16/499] Processing: part-00016-of-00500.csv.gz
# [17/499] Processing: part-00017-of-00500.csv.gz
# [18/499] Processing: part-00018-of-00500.csv.gz
# [19/499] Processing: part-00019-of-00500.csv.gz
# [20/499] Processing: part-00020-of-00500.csv.gz
# [21/499] Processing: part-00021-of-00500.csv.gz
# [22/499] Processing: part-00022-of-00500.csv.gz
# [23/499] Processing: part-00023-of-00500.csv.gz
# [24/499] Processing: part-00024-of-00500.csv.gz
# [25/499] Processing: part-00025-of-00500.csv.gz
# [26/499] Processing: part-00026-of-00500.csv.gz
# [27/499] Processing: part-00027-of-00500.csv.gz
# [28/499] Processing: part-00028-of-00500.csv.gz
# [29/499] Processing: part-00029-of-00500.csv.gz
# [30/499] Processing: part-00030-of-00500.csv.gz
# [31/499] Processing: part-00031-of-00500.csv.gz
# [32/499] Processing: part-00032-of-00500.csv.gz
# [33/499] Processing: part-00033-of-00500.csv.gz
# [34/499] Processing: part-00034-of-00500.csv.gz
# [35/499] Processing: part-00035-of-00500.csv.gz
# [36/499] Processing: part-00036-of-00500.csv.gz
# [37/499] Processing: part-00037-of-00500.csv.gz
# [38/499] Processing: part-00038-of-00500.csv.gz
# [39/499] Processing: part-00039-of-00500.csv.gz
# [40/499] Processing: part-00040-of-00500.csv.gz
# [41/499] Processing: part-00041-of-00500.csv.gz
# [42/499] Processing: part-00042-of-00500.csv.gz
# [43/499] Processing: part-00043-of-00500.csv.gz
# [44/499] Processing: part-00044-of-00500.csv.gz
    chunk_number += 1
    print(f"Processing chunk {chunk_number}")

    end_time = chunk.iloc[:, END_TIME_COL]
    machine_id = chunk.iloc[:, MACHINE_ID_COL]
    cpu = chunk.iloc[:, CPU_COL]
    memory = chunk.iloc[:, MEM_COL]

    window = (end_time // WINDOW) * WINDOW

    for w, mid, c, m in zip(window, machine_id, cpu, memory):

        key = (w, mid)

        if key not in agg_dict:
            # [task_count, cpu_sum, mem_sum]
            agg_dict[key] = [0, 0.0, 0.0]

        agg_dict[key][0] += 1
        agg_dict[key][1] += c
        agg_dict[key][2] += m


# Convert dictionary to DataFrame
rows = []

for (w, mid), values in agg_dict.items():
    count, cpu_sum, mem_sum = values
    rows.append([
        w,
        mid,
        count,
        cpu_sum / count,
        mem_sum / count
    ])

final_df = pd.DataFrame(
    rows,
    columns=["window", "machine_id", "task_count", "avg_cpu", "avg_memory"]
)

final_df.sort_values(["window", "machine_id"], inplace=True)

final_df.to_csv(output_file, index=False)

print("✅ Machine-wise 5-min aggregation saved.")
# Out:
# Processing chunk 1
# Processing chunk 2
# Processing chunk 3
# Processing chunk 4
# Processing chunk 5
# Processing chunk 6
# Processing chunk 7
# Processing chunk 8
# Processing chunk 9
# Processing chunk 10
# Processing chunk 11
# Processing chunk 12
# Processing chunk 13
# Processing chunk 14
# Processing chunk 15
# Processing chunk 16
# Processing chunk 17
# Processing chunk 18
# Processing chunk 19
# Processing chunk 20
# Processing chunk 21
# Processing chunk 22
# Processing chunk 23
# Processing chunk 24
# Processing chunk 25
# Processing chunk 26
# Processing chunk 27
# Processing chunk 28
# Processing chunk 29
# Processing chunk 30
# Processing chunk 31
# Processing chunk 32
# Processing chunk 33
# Processing chunk 34
# Processing chunk 35
# Processing chunk 36
# Processing chunk 37
# Processing chunk 38
# Processing chunk 39
# Processing chunk 40
# Processing chunk 41
# Processing chunk 42
# Processing chunk 43
# Processing chunk 44
# Processing chunk 45
# Processing chunk 46
# Processing chunk 47
# Processing chunk 48
# Processing chunk 49
# Processing chunk 50
# Processing chunk 51
# Processing chunk 52
# Processing chunk 53
# Processing chunk 54
# Processing chunk 55
# Processing chunk 56
# Processing chunk 57
# Processing chunk 58
# Processing chunk 59
# Processing chunk 60
# Processing chunk 61
# Processing chunk 62
# Processing chunk 63
# Processing chunk 64
# Processing chunk 65
# Processing chunk 66
# Processing chunk 67
# Processing chunk 68
# Processing chunk 69
# Processing chunk 70
# Processing chunk 71
# Processing chunk 72
# Processing chunk 73
# Processing chunk 74
# Processing chunk 75
# Processing chunk 76
# Processing chunk 77
# Processing chunk 78
# Processing chunk 79
# Processing chunk 80
# Processing chunk 81
# Processing chunk 82
# Processing chunk 83
# Processing chunk 84
# Processing chunk 85
# Processing chunk 86
# Processing chunk 87
# Processing chunk 88
# Processing chunk 89
# Processing chunk 90
# Processing chunk 91
# Processing chunk 92
# Processing chunk 93
# Processing chunk 94
# Processing chunk 95
# Processing chunk 96
# Processing chunk 97
# Processing chunk 98
# Processing chunk 99
# Processing chunk 100
# Processing chunk 101
# Processing chunk 102
# Processing chunk 103
# Processing chunk 104
# Processing chunk 105
# Processing chunk 106
# Processing chunk 107
# Processing chunk 108
# Processing chunk 109
# Processing chunk 110
# Processing chunk 111
# Processing chunk 112
# Processing chunk 113
# Processing chunk 114
# Processing chunk 115
# Processing chunk 116
# Processing chunk 117
# Processing chunk 118
# Processing chunk 119
# Processing chunk 120
# Processing chunk 121
# Processing chunk 122
# Processing chunk 123
# Processing chunk 124
# Processing chunk 125
# Processing chunk 126
# Processing chunk 127
# Processing chunk 128
# Processing chunk 129
# Processing chunk 130
# Processing chunk 131
# Processing chunk 132
# Processing chunk 133
# Processing chunk 134
# Processing chunk 135
# Processing chunk 136
# Processing chunk 137
# Processing chunk 138
# Processing chunk 139
# Processing chunk 140
# Processing chunk 141
# Processing chunk 142
# Processing chunk 143
# Processing chunk 144
# Processing chunk 145
# Processing chunk 146
# Processing chunk 147
# Processing chunk 148
# Processing chunk 149
# Processing chunk 150
# Processing chunk 151
# Processing chunk 152
# Processing chunk 153
# Processing chunk 154
# Processing chunk 155
# Processing chunk 156
# Processing chunk 157
# Processing chunk 158
# Processing chunk 159
# Processing chunk 160
# Processing chunk 161
# Processing chunk 162
# Processing chunk 163
# Processing chunk 164
# Processing chunk 165
# Processing chunk 166
# Processing chunk 167
# Processing chunk 168
# Processing chunk 169
# Processing chunk 170
# Processing chunk 171
# Processing chunk 172
# Processing chunk 173
# Processing chunk 174
# Processing chunk 175
# Processing chunk 176
# Processing chunk 177
# Processing chunk 178
# Processing chunk 179
# Processing chunk 180
# Processing chunk 181
# Processing chunk 182
# Processing chunk 183
# Processing chunk 184
# Processing chunk 185
# Processing chunk 186
# Processing chunk 187
# Processing chunk 188
# Processing chunk 189
# Processing chunk 190
# Processing chunk 191
# Processing chunk 192
# Processing chunk 193
# Processing chunk 194
# Processing chunk 195
# Processing chunk 196
# Processing chunk 197
# Processing chunk 198
# Processing chunk 199
# Processing chunk 200
# Processing chunk 201
# Processing chunk 202
# Processing chunk 203
# Processing chunk 204
# Processing chunk 205
# Processing chunk 206
# Processing chunk 207
# Processing chunk 208
# Processing chunk 209
# Processing chunk 210
# Processing chunk 211
# Processing chunk 212
# Processing chunk 213
# Processing chunk 214
# Processing chunk 215
# Processing chunk 216
# Processing chunk 217
# Processing chunk 218
# Processing chunk 219
# Processing chunk 220
# Processing chunk 221
# Processing chunk 222
# Processing chunk 223
# Processing chunk 224
# Processing chunk 225
# Processing chunk 226
# Processing chunk 227
# Processing chunk 228
# Processing chunk 229
# Processing chunk 230
# Processing chunk 231
# Processing chunk 232
# Processing chunk 233
# Processing chunk 234
# Processing chunk 235
# Processing chunk 236
# Processing chunk 237
# Processing chunk 238
# Processing chunk 239
# Processing chunk 240
# Processing chunk 241
# Processing chunk 242
# Processing chunk 243
# Processing chunk 244
# Processing chunk 245
# Processing chunk 246
# Processing chunk 247
# Processing chunk 248
# Processing chunk 249
# Processing chunk 250
# Processing chunk 251
# Processing chunk 252
# Processing chunk 253
# Processing chunk 254
# Processing chunk 255
# Processing chunk 256
# Processing chunk 257
# Processing chunk 258
# Processing chunk 259
# Processing chunk 260
# Processing chunk 261
# Processing chunk 262
# Processing chunk 263
# Processing chunk 264
# Processing chunk 265
# Processing chunk 266
# Processing chunk 267
# Processing chunk 268
# Processing chunk 269
# Processing chunk 270
# Processing chunk 271
# Processing chunk 272
# Processing chunk 273
# Processing chunk 274
# Processing chunk 275
# Processing chunk 276
# Processing chunk 277
# Processing chunk 278
# Processing chunk 279
# Processing chunk 280
# Processing chunk 281
# Processing chunk 282
# Processing chunk 283
# Processing chunk 284
# Processing chunk 285
# Processing chunk 286
# Processing chunk 287
# Processing chunk 288
# Processing chunk 289
# Processing chunk 290
# Processing chunk 291
# Processing chunk 292
# Processing chunk 293
# Processing chunk 294
# Processing chunk 295
# Processing chunk 296
# Processing chunk 297
# Processing chunk 298
# Processing chunk 299
# Processing chunk 300
# Processing chunk 301
# Processing chunk 302
# Processing chunk 303
# Processing chunk 304
# Processing chunk 305
# Processing chunk 306
# Processing chunk 307
# Processing chunk 308
# Processing chunk 309
# Processing chunk 310
# Processing chunk 311
# Processing chunk 312
# Processing chunk 313
# Processing chunk 314
# Processing chunk 315
# Processing chunk 316
# Processing chunk 317
# Processing chunk 318
# Processing chunk 319
# Processing chunk 320
# Processing chunk 321
# Processing chunk 322
# Processing chunk 323
# Processing chunk 324
# Processing chunk 325
# Processing chunk 326
# Processing chunk 327
# Processing chunk 328
# Processing chunk 329
# Processing chunk 330
# Processing chunk 331
# Processing chunk 332
# Processing chunk 333
# Processing chunk 334
# Processing chunk 335
# Processing chunk 336
# Processing chunk 337
# Processing chunk 338
# Processing chunk 339
# Processing chunk 340
# Processing chunk 341
# Processing chunk 342
# Processing chunk 343
# Processing chunk 344
# Processing chunk 345
# Processing chunk 346
# Processing chunk 347
# Processing chunk 348
# Processing chunk 349
# Processing chunk 350
# Processing chunk 351
# Processing chunk 352
# Processing chunk 353
# Processing chunk 354
# Processing chunk 355
# Processing chunk 356
# Processing chunk 357
# Processing chunk 358
# Processing chunk 359
# Processing chunk 360
# Processing chunk 361
# Processing chunk 362
# Processing chunk 363
# Processing chunk 364
# Processing chunk 365
# Processing chunk 366
# Processing chunk 367
# Processing chunk 368
# Processing chunk 369
# Processing chunk 370
# Processing chunk 371
# Processing chunk 372
# Processing chunk 373
# Processing chunk 374
# Processing chunk 375
# Processing chunk 376
# Processing chunk 377
# Processing chunk 378
# Processing chunk 379
# Processing chunk 380
# Processing chunk 381
# Processing chunk 382
# Processing chunk 383
# Processing chunk 384
# Processing chunk 385
# Processing chunk 386
# Processing chunk 387
# Processing chunk 388
# Processing chunk 389
# Processing chunk 390
# Processing chunk 391
# Processing chunk 392
# Processing chunk 393
# Processing chunk 394
# Processing chunk 395
# Processing chunk 396
# Processing chunk 397
# Processing chunk 398
# Processing chunk 399
# Processing chunk 400
# Processing chunk 401
# Processing chunk 402
# Processing chunk 403
# Processing chunk 404
# Processing chunk 405
# Processing chunk 406
# Processing chunk 407
# Processing chunk 408
# Processing chunk 409
# Processing chunk 410
# Processing chunk 411
# Processing chunk 412
# Processing chunk 413
# Processing chunk 414
# Processing chunk 415
# Processing chunk 416
# Processing chunk 417
# Processing chunk 418
# Processing chunk 419
# Processing chunk 420
# Processing chunk 421
# Processing chunk 422
# Processing chunk 423
# Processing chunk 424
# Processing chunk 425
# Processing chunk 426
# Processing chunk 427
# Processing chunk 428
# Processing chunk 429
# Processing chunk 430
# Processing chunk 431
# Processing chunk 432
# Processing chunk 433
# Processing chunk 434
# Processing chunk 435
# Processing chunk 436
# Processing chunk 437
# Processing chunk 438
# Processing chunk 439
# Processing chunk 440
# Processing chunk 441
# Processing chunk 442
# Processing chunk 443
# Processing chunk 444
# Processing chunk 445
# Processing chunk 446
# Processing chunk 447
# Processing chunk 448
# Processing chunk 449
# Processing chunk 450
# Processing chunk 451
# Processing chunk 452
# Processing chunk 453
# Processing chunk 454
# Processing chunk 455
# Processing chunk 456
# Processing chunk 457
# Processing chunk 458
# Processing chunk 459
# Processing chunk 460
# Processing chunk 461
# Processing chunk 462
# Processing chunk 463
# Processing chunk 464
# Processing chunk 465
# Processing chunk 466
# Processing chunk 467
# Processing chunk 468
# Processing chunk 469
# Processing chunk 470
# Processing chunk 471
# Processing chunk 472
# Processing chunk 473
# Processing chunk 474
# Processing chunk 475
# Processing chunk 476
# Processing chunk 477
# Processing chunk 478
# Processing chunk 479
# Processing chunk 480
# Processing chunk 481
# Processing chunk 482
# Processing chunk 483
# Processing chunk 484
# Processing chunk 485
# Processing chunk 486
# Processing chunk 487
# Processing chunk 488
# Processing chunk 489
# Processing chunk 490
# Processing chunk 491
# Processing chunk 492
# Processing chunk 493
# Processing chunk 494
# Processing chunk 495
# Processing chunk 496
# Processing chunk 497
# Processing chunk 498
# Processing chunk 499
# Processing chunk 500
# Processing chunk 501
# Processing chunk 502
# Processing chunk 503
# Processing chunk 504
# Processing chunk 505
# Processing chunk 506
# Processing chunk 507
# Processing chunk 508
# Processing chunk 509
# Processing chunk 510
# Processing chunk 511
# Processing chunk 512
# Processing chunk 513
# Processing chunk 514
# Processing chunk 515
# Processing chunk 516
# Processing chunk 517
# Processing chunk 518
# Processing chunk 519
# Processing chunk 520
# Processing chunk 521
# Processing chunk 522
# Processing chunk 523
# Processing chunk 524
# Processing chunk 525
# Processing chunk 526
# Processing chunk 527
# Processing chunk 528
# Processing chunk 529
# Processing chunk 530
# Processing chunk 531
# Processing chunk 532
# Processing chunk 533
# Processing chunk 534
# Processing chunk 535
# Processing chunk 536
# Processing chunk 537
# Processing chunk 538
# Processing chunk 539
# Processing chunk 540
# Processing chunk 541
# Processing chunk 542
# Processing chunk 543
# Processing chunk 544
# Processing chunk 545
# Processing chunk 546
# Processing chunk 547
# Processing chunk 548
# Processing chunk 549
# Processing chunk 550
# Processing chunk 551
# Processing chunk 552
# Processing chunk 553
# Processing chunk 554
# Processing chunk 555
# Processing chunk 556
# Processing chunk 557
# Processing chunk 558
# Processing chunk 559
# Processing chunk 560
# Processing chunk 561
# Processing chunk 562
# Processing chunk 563
# Processing chunk 564
# Processing chunk 565
# Processing chunk 566
# Processing chunk 567
# Processing chunk 568
# Processing chunk 569
# Processing chunk 570
# Processing chunk 571
# Processing chunk 572
# Processing chunk 573
# Processing chunk 574
# Processing chunk 575
# Processing chunk 576
# Processing chunk 577
# Processing chunk 578
# Processing chunk 579
# Processing chunk 580
# Processing chunk 581
# Processing chunk 582
# Processing chunk 583
# Processing chunk 584
# Processing chunk 585
# Processing chunk 586
# Processing chunk 587
# Processing chunk 588
# Processing chunk 589
# Processing chunk 590
# Processing chunk 591
# Processing chunk 592
# Processing chunk 593
# Processing chunk 594
# Processing chunk 595
# Processing chunk 596
# Processing chunk 597
# Processing chunk 598
# Processing chunk 599
# Processing chunk 600
# Processing chunk 601
# Processing chunk 602
# Processing chunk 603
# Processing chunk 604
# Processing chunk 605
# Processing chunk 606
# Processing chunk 607
# Processing chunk 608
# Processing chunk 609
# Processing chunk 610
# Processing chunk 611
# Processing chunk 612
# Processing chunk 613
# Processing chunk 614
# Processing chunk 615
# Processing chunk 616
# Processing chunk 617
# Processing chunk 618
# Processing chunk 619
# Processing chunk 620
# Processing chunk 621
# Processing chunk 622
# Processing chunk 623
# Processing chunk 624
# Processing chunk 625
# Processing chunk 626
# Processing chunk 627
# Processing chunk 628
# Processing chunk 629
# Processing chunk 630
# Processing chunk 631
# Processing chunk 632
# Processing chunk 633
# Processing chunk 634
# Processing chunk 635
# Processing chunk 636
# Processing chunk 637
# Processing chunk 638
# Processing chunk 639
# Processing chunk 640
# Processing chunk 641
# Processing chunk 642
# Processing chunk 643
# Processing chunk 644
# Processing chunk 645
# Processing chunk 646
# Processing chunk 647
# Processing chunk 648
# Processing chunk 649
# Processing chunk 650
# Processing chunk 651
# Processing chunk 652
# Processing chunk 653
# Processing chunk 654
# Processing chunk 655
# Processing chunk 656
# Processing chunk 657
# Processing chunk 658
# Processing chunk 659
# Processing chunk 660
# Processing chunk 661
# Processing chunk 662
# Processing chunk 663
# Processing chunk 664
# Processing chunk 665
# Processing chunk 666
# Processing chunk 667
# Processing chunk 668
# Processing chunk 669
# Processing chunk 670
# Processing chunk 671
# Processing chunk 672
# Processing chunk 673
# Processing chunk 674
# Processing chunk 675
# Processing chunk 676
# Processing chunk 677
# Processing chunk 678
# Processing chunk 679
# Processing chunk 680
# Processing chunk 681
# Processing chunk 682
# Processing chunk 683
# Processing chunk 684
# Processing chunk 685
# Processing chunk 686
# Processing chunk 687
# Processing chunk 688
# Processing chunk 689
# Processing chunk 690
# Processing chunk 691
# Processing chunk 692
# Processing chunk 693
# Processing chunk 694
# Processing chunk 695
# Processing chunk 696
# Processing chunk 697
# Processing chunk 698
# Processing chunk 699
# Processing chunk 700
# Processing chunk 701
# Processing chunk 702
# Processing chunk 703
# Processing chunk 704
# Processing chunk 705
# Processing chunk 706
# Processing chunk 707
# Processing chunk 708
# Processing chunk 709
# Processing chunk 710
# Processing chunk 711
# Processing chunk 712
# Processing chunk 713
# Processing chunk 714
# Processing chunk 715
# Processing chunk 716
# Processing chunk 717
# Processing chunk 718
# Processing chunk 719
# Processing chunk 720
# Processing chunk 721
# Processing chunk 722
# Processing chunk 723
# Processing chunk 724
# Processing chunk 725
# Processing chunk 726
# Processing chunk 727
# Processing chunk 728
# Processing chunk 729
# Processing chunk 730
# Processing chunk 731
# Processing chunk 732
# Processing chunk 733
# Processing chunk 734
# Processing chunk 735
# Processing chunk 736
# Processing chunk 737
# Processing chunk 738
# Processing chunk 739
# Processing chunk 740
# Processing chunk 741
# Processing chunk 742
# Processing chunk 743
# Processing chunk 744
# Processing chunk 745
# Processing chunk 746
# Processing chunk 747
# Processing chunk 748
# Processing chunk 749
# Processing chunk 750
# Processing chunk 751
# Processing chunk 752
# Processing chunk 753
# Processing chunk 754
# Processing chunk 755
# Processing chunk 756
# Processing chunk 757
# Processing chunk 758
# Processing chunk 759
# Processing chunk 760
# Processing chunk 761
# Processing chunk 762
# Processing chunk 763
# Processing chunk 764
# Processing chunk 765
# Processing chunk 766
# Processing chunk 767
# Processing chunk 768
# Processing chunk 769
# Processing chunk 770
# Processing chunk 771
# Processing chunk 772
# Processing chunk 773
# Processing chunk 774
# Processing chunk 775
# Processing chunk 776
# Processing chunk 777
# Processing chunk 778
# Processing chunk 779
# Processing chunk 780
# Processing chunk 781
# Processing chunk 782
# Processing chunk 783
# Processing chunk 784
# Processing chunk 785
# Processing chunk 786
# Processing chunk 787
# Processing chunk 788
# Processing chunk 789
# Processing chunk 790
# Processing chunk 791
# Processing chunk 792
# Processing chunk 793
# Processing chunk 794
# Processing chunk 795
# Processing chunk 796
# Processing chunk 797
# Processing chunk 798
# Processing chunk 799
# Processing chunk 800
# Processing chunk 801
# Processing chunk 802
# Processing chunk 803
# Processing chunk 804
# Processing chunk 805
# Processing chunk 806
# Processing chunk 807
# Processing chunk 808
# Processing chunk 809
# Processing chunk 810
# Processing chunk 811
# Processing chunk 812
# Processing chunk 813
# Processing chunk 814
# Processing chunk 815
# Processing chunk 816
# Processing chunk 817
# Processing chunk 818
# Processing chunk 819
# Processing chunk 820
# Processing chunk 821
# Processing chunk 822
# Processing chunk 823
# Processing chunk 824
# Processing chunk 825
# Processing chunk 826
# Processing chunk 827
# Processing chunk 828
# Processing chunk 829
# Processing chunk 830
# Processing chunk 831
# Processing chunk 832
# Processing chunk 833
# Processing chunk 834
# Processing chunk 835
# Processing chunk 836
# Processing chunk 837
# Processing chunk 838
# Processing chunk 839
# Processing chunk 840
# Processing chunk 841
# Processing chunk 842
# Processing chunk 843
# Processing chunk 844
# Processing chunk 845
# Processing chunk 846
# Processing chunk 847
# Processing chunk 848
# Processing chunk 849
# Processing chunk 850
# Processing chunk 851
# Processing chunk 852
# Processing chunk 853
# Processing chunk 854
# Processing chunk 855
# Processing chunk 856
# Processing chunk 857
# Processing chunk 858
# Processing chunk 859
# Processing chunk 860
# Processing chunk 861
# Processing chunk 862
# Processing chunk 863
# Processing chunk 864
# Processing chunk 865
# Processing chunk 866
# Processing chunk 867
# Processing chunk 868
# Processing chunk 869
# Processing chunk 870
# Processing chunk 871
# Processing chunk 872
# Processing chunk 873
# Processing chunk 874
# Processing chunk 875
# Processing chunk 876
# Processing chunk 877
# Processing chunk 878
# Processing chunk 879
# Processing chunk 880
# Processing chunk 881
# Processing chunk 882
# Processing chunk 883
# Processing chunk 884
# Processing chunk 885
# Processing chunk 886
# Processing chunk 887
# Processing chunk 888
# Processing chunk 889
# Processing chunk 890
# Processing chunk 891
# Processing chunk 892
# Processing chunk 893
# Processing chunk 894
# Processing chunk 895
# Processing chunk 896
# Processing chunk 897
# Processing chunk 898
# Processing chunk 899
# Processing chunk 900
# Processing chunk 901
# Processing chunk 902
# Processing chunk 903
# Processing chunk 904
# Processing chunk 905
# Processing chunk 906
# Processing chunk 907
# Processing chunk 908
# Processing chunk 909
# Processing chunk 910
# Processing chunk 911
# Processing chunk 912
# Processing chunk 913
# Processing chunk 914
# Processing chunk 915
# Processing chunk 916
# Processing chunk 917
# Processing chunk 918
# Processing chunk 919
# Processing chunk 920
# Processing chunk 921
# Processing chunk 922
# Processing chunk 923
# Processing chunk 924
# Processing chunk 925
# Processing chunk 926
# Processing chunk 927
# Processing chunk 928
# Processing chunk 929
# Processing chunk 930
# Processing chunk 931
# Processing chunk 932
# Processing chunk 933
# Processing chunk 934
# Processing chunk 935
# Processing chunk 936
# Processing chunk 937
# Processing chunk 938
# Processing chunk 939
# Processing chunk 940
# Processing chunk 941
# Processing chunk 942
# Processing chunk 943
# Processing chunk 944
# Processing chunk 945
# Processing chunk 946
# Processing chunk 947
# Processing chunk 948
# Processing chunk 949
# Processing chunk 950
# Processing chunk 951
# Processing chunk 952
# Processing chunk 953
# Processing chunk 954
# Processing chunk 955
# Processing chunk 956
# Processing chunk 957
# Processing chunk 958
# Processing chunk 959
# Processing chunk 960
# Processing chunk 961
# Processing chunk 962
# Processing chunk 963
# Processing chunk 964
# Processing chunk 965
# Processing chunk 966
# Processing chunk 967
# Processing chunk 968
# Processing chunk 969
# Processing chunk 970
# Processing chunk 971
# Processing chunk 972
# Processing chunk 973
# Processing chunk 974
# Processing chunk 975
# Processing chunk 976
# Processing chunk 977
# Processing chunk 978
# Processing chunk 979
# Processing chunk 980
# Processing chunk 981
# Processing chunk 982
# Processing chunk 983
# Processing chunk 984
# Processing chunk 985
# Processing chunk 986
# Processing chunk 987
# Processing chunk 988
# Processing chunk 989
# Processing chunk 990
# Processing chunk 991
# Processing chunk 992
# Processing chunk 993
# Processing chunk 994
# Processing chunk 995
# Processing chunk 996
# Processing chunk 997
# Processing chunk 998
# Processing chunk 999
# Processing chunk 1000
# Processing chunk 1001
# Processing chunk 1002
# Processing chunk 1003
# Processing chunk 1004
# Processing chunk 1005
# Processing chunk 1006
# Processing chunk 1007
# Processing chunk 1008
# Processing chunk 1009
# Processing chunk 1010
# Processing chunk 1011
# Processing chunk 1012
# Processing chunk 1013
# Processing chunk 1014
# Processing chunk 1015
# Processing chunk 1016
# Processing chunk 1017
# Processing chunk 1018
# Processing chunk 1019
# Processing chunk 1020
# Processing chunk 1021
# Processing chunk 1022
# Processing chunk 1163
# Processing chunk 1164
# Processing chunk 1165
# Processing chunk 1166
# Processing chunk 1167
# Processing chunk 1168
# Processing chunk 1169
# Processing chunk 1170
# Processing chunk 1171
# Processing chunk 1172
# Processing chunk 1173
# Processing chunk 1174
# Processing chunk 1175
# Processing chunk 1176
# Processing chunk 1177
# Processing chunk 1178
# Processing chunk 1179
# Processing chunk 1180
# Processing chunk 1181
# Processing chunk 1182
# Processing chunk 1183
# Processing chunk 1184
# Processing chunk 1185
# Processing chunk 1186
# Processing chunk 1187
# Processing chunk 1188
# Processing chunk 1189
# Processing chunk 1190
# Processing chunk 1191
# Processing chunk 1192
# Processing chunk 1193
# Processing chunk 1194
# Processing chunk 1195
# Processing chunk 1196
# Processing chunk 1197
# Processing chunk 1198
# Processing chunk 1199
# Processing chunk 1200
# Processing chunk 1201
# Processing chunk 1202
# Processing chunk 1203
# Processing chunk 1204
# Processing chunk 1205
# Processing chunk 1206
# Processing chunk 1207
# Processing chunk 1208
# Processing chunk 1209
# Processing chunk 1210
# Processing chunk 1211
# Processing chunk 1212
# Processing chunk 1213
# Processing chunk 1214
# Processing chunk 1215
# Processing chunk 1216
# Processing chunk 1217
# Processing chunk 1218
# Processing chunk 1219
# Processing chunk 1220
# Processing chunk 1221
# Processing chunk 1222
# Processing chunk 1223
# Processing chunk 1224
# Processing chunk 1225
# Processing chunk 1226
# Processing chunk 1227
# Processing chunk 1228
# Processing chunk 1229
# Processing chunk 1230
# Processing chunk 1231
# Processing chunk 1232
# Processing chunk 1233
# Processing chunk 1234
# Processing chunk 1235
# Processing chunk 1236
# Processing chunk 1237
# Processing chunk 1238
# Processing chunk 1239
# Processing chunk 1240
# Processing chunk 1241
# Processing chunk 1242
# Processing chunk 1243
# Processing chunk 1244
# Processing chunk 1245
# Processing chunk 1246
# Processing chunk 1247
# Processing chunk 1248
# Processing chunk 1249
# Processing chunk 1250
# Processing chunk 1251
# Processing chunk 1252
# Processing chunk 1253
# Processing chunk 1254
# Processing chunk 1255
# Processing chunk 1256
# Processing chunk 1257
# Processing chunk 1258
# Processing chunk 1259
# Processing chunk 1260
# Processing chunk 1261
# Processing chunk 1262
# Processing chunk 1263
# Processing chunk 1264
# Processing chunk 1265
# Processing chunk 1266
# Processing chunk 1267
# Processing chunk 1268
# Processing chunk 1269
# Processing chunk 1270
# Processing chunk 1271
# Processing chunk 1272
# Processing chunk 1273
# Processing chunk 1274
# Processing chunk 1275
# Processing chunk 1276
# Processing chunk 1277
# Processing chunk 1278
# Processing chunk 1279
# Processing chunk 1280
# Processing chunk 1281
# Processing chunk 1282
# Processing chunk 1283
# Processing chunk 1284
# Processing chunk 1285
# Processing chunk 1286
# Processing chunk 1287
# Processing chunk 1288
# Processing chunk 1289
# Processing chunk 1290
# Processing chunk 1291
# Processing chunk 1292
# Processing chunk 1293
# Processing chunk 1294
# Processing chunk 1295
# Processing chunk 1296
# Processing chunk 1297
# Processing chunk 1298
# Processing chunk 1299
# Processing chunk 1300
# Processing chunk 1301
# Processing chunk 1302
# Processing chunk 2002
# Processing chunk 2003
# Processing chunk 2004
# Processing chunk 2005
# Processing chunk 2006
# Processing chunk 2007
# Processing chunk 2008
# Processing chunk 2009
# Processing chunk 2010
# Processing chunk 2011
# Processing chunk 2012
# Processing chunk 2013
# Processing chunk 2014
# Processing chunk 2015
# Processing chunk 2016
# Processing chunk 2017
# Processing chunk 2018
# Processing chunk 2019
# Processing chunk 2020
# Processing chunk 2021
# Processing chunk 2022
# Processing chunk 2023
# Processing chunk 2024
# Processing chunk 2025
# Processing chunk 2026
# Processing chunk 2027
# Processing chunk 2028
# Processing chunk 2029
# Processing chunk 2030
# Processing chunk 2031
# Processing chunk 2032
# Processing chunk 2033
# Processing chunk 2034
# Processing chunk 2035
# Processing chunk 2036
# Processing chunk 2037
# Processing chunk 2038
# Processing chunk 2039
# Processing chunk 2040
# Processing chunk 2041
# Processing chunk 2042
# Processing chunk 2043
# Processing chunk 2044
# Processing chunk 2045
# Processing chunk 2046
# Processing chunk 2047
# Processing chunk 2048
# Processing chunk 2049
# Processing chunk 2050
# Processing chunk 2051
# Processing chunk 2052
# Processing chunk 2053
# Processing chunk 2054
# Processing chunk 2055
# Processing chunk 2056
# Processing chunk 2057
# Processing chunk 2058
# Processing chunk 2059
# Processing chunk 2060
# Processing chunk 2061
# Processing chunk 2062
# Processing chunk 2063
# Processing chunk 2064
# Processing chunk 2065
# Processing chunk 2066
# Processing chunk 2067
# Processing chunk 2068
# Processing chunk 2069
# Processing chunk 2070
# Processing chunk 2071
# Processing chunk 2072
# Processing chunk 2073
# Processing chunk 2074
# Processing chunk 2075
# Processing chunk 2076
# Processing chunk 2077
# Processing chunk 2078
# Processing chunk 2079
# Processing chunk 2080
# Processing chunk 2081
# Processing chunk 2082
# Processing chunk 2083
# Processing chunk 2084
# Processing chunk 2085
# Processing chunk 2086
# Processing chunk 2087
# Processing chunk 2088
# Processing chunk 2089
# Processing chunk 2090
# Processing chunk 2091
# Processing chunk 2092
# Processing chunk 2093
# Processing chunk 2094
# Processing chunk 2095
# Processing chunk 2096
# Processing chunk 2097
# Processing chunk 2098
# Processing chunk 2099
# Processing chunk 2100
# Processing chunk 2101
# Processing chunk 2102
# Processing chunk 2103
# Processing chunk 2104
# Processing chunk 2105
# Processing chunk 2106
# Processing chunk 2107
# Processing chunk 2108
# Processing chunk 2109
# Processing chunk 2110
# Processing chunk 2111
# Processing chunk 2112
# Processing chunk 2113
# Processing chunk 2114
# Processing chunk 2115
# Processing chunk 2116
# Processing chunk 2117
# Processing chunk 2118
# Processing chunk 2119
# Processing chunk 2120
# Processing chunk 2121
# Processing chunk 2122
# Processing chunk 2123
# Processing chunk 2124
# Processing chunk 2125
# Processing chunk 2126
# Processing chunk 2127
# Processing chunk 2128
# Processing chunk 2129
# Processing chunk 2130
# Processing chunk 2131
# Processing chunk 2132
# Processing chunk 2133
# Processing chunk 2134
# Processing chunk 2135
# Processing chunk 2136
# Processing chunk 2137
# Processing chunk 2138
# Processing chunk 2139
# Processing chunk 2140
# Processing chunk 2141
# Processing chunk 2142
# Processing chunk 2143
# Processing chunk 2144
# Processing chunk 2145
# Processing chunk 2146
# Processing chunk 2147
# Processing chunk 2148
# Processing chunk 2149
# Processing chunk 2150
# Processing chunk 2151
# Processing chunk 2152
# Processing chunk 2153
# Processing chunk 2154
# Processing chunk 2155
# Processing chunk 2156
# Processing chunk 2157
# Processing chunk 2158
# Processing chunk 2159
# Processing chunk 2160
# Processing chunk 2161
# Processing chunk 2162
# Processing chunk 2163
# Processing chunk 2164
# Processing chunk 2165
# Processing chunk 2166
# Processing chunk 2167
# Processing chunk 2168
# Processing chunk 2169
# Processing chunk 2170
# Processing chunk 2171
# Processing chunk 2172
# Processing chunk 2173
# Processing chunk 2174
# Processing chunk 2175
# Processing chunk 2176
# Processing chunk 2177
# Processing chunk 2178
# Processing chunk 2179
# Processing chunk 2180
# Processing chunk 2181
# Processing chunk 2182
# Processing chunk 2183
# Processing chunk 2184
# Processing chunk 2185
# Processing chunk 2186
# Processing chunk 2187
# Processing chunk 2188
# Processing chunk 2189
# Processing chunk 2190
# Processing chunk 2191
# Processing chunk 2192
# Processing chunk 2193
# Processing chunk 2194
# Processing chunk 2195
# Processing chunk 2196
# Processing chunk 2197
# Processing chunk 2198
# Processing chunk 2199
# Processing chunk 2200
# Processing chunk 2201
# Processing chunk 2202
# Processing chunk 2203
# Processing chunk 2204
# Processing chunk 2205
# Processing chunk 2206
# Processing chunk 2207
# Processing chunk 2208
# Processing chunk 2209
# Processing chunk 2210
# Processing chunk 2211
# Processing chunk 2212
# Processing chunk 2213
# Processing chunk 2214
# Processing chunk 2215
# Processing chunk 2216
# Processing chunk 2217
# Processing chunk 2218
# Processing chunk 2219
# Processing chunk 2220
# Processing chunk 2221
# Processing chunk 2222
# Processing chunk 2223
# Processing chunk 2224
# Processing chunk 2225
# Processing chunk 2226
# Processing chunk 2227
# Processing chunk 2228
# Processing chunk 2229
# Processing chunk 2230
# Processing chunk 2231
# Processing chunk 2232
# Processing chunk 2233
# Processing chunk 2234
# Processing chunk 2235
# Processing chunk 2236
# Processing chunk 2237
# Processing chunk 2238
# Processing chunk 2239
# Processing chunk 2240
# Processing chunk 2241
# Processing chunk 2242
# Processing chunk 2243
# Processing chunk 2244
# Processing chunk 2245
# Processing chunk 2246
# Processing chunk 2247
# Processing chunk 2248
# Processing chunk 2249
# Processing chunk 2250
# Processing chunk 2251
# Processing chunk 2252
# Processing chunk 2253
# Processing chunk 2254
# Processing chunk 2255
# Processing chunk 2256
# Processing chunk 2257
# Processing chunk 2258
# Processing chunk 2259
# Processing chunk 2260
# Processing chunk 2261
# Processing chunk 2262
# Processing chunk 2263
# Processing chunk 2264
# Processing chunk 2265
# Processing chunk 2266
# Processing chunk 2267
# Processing chunk 2268
# Processing chunk 2269
# Processing chunk 2270
# Processing chunk 2271
# Processing chunk 2272
# Processing chunk 2273
# Processing chunk 2274
# Processing chunk 2275
# Processing chunk 2276
# Processing chunk 2277
# Processing chunk 2278
# Processing chunk 2279
# Processing chunk 2280
# Processing chunk 2281
# Processing chunk 2282
# Processing chunk 2283
# Processing chunk 2284
# Processing chunk 2285
# Processing chunk 2286
# Processing chunk 2287
# Processing chunk 2288
# Processing chunk 2289
# Processing chunk 2290
# Processing chunk 2291
# Processing chunk 2292
# Processing chunk 2293
# Processing chunk 2294
# Processing chunk 2295
# Processing chunk 2296
# Processing chunk 2297
# Processing chunk 2298
# Processing chunk 2299
# Processing chunk 2300
# Processing chunk 2301
# Processing chunk 2302
# Processing chunk 2303
# Processing chunk 2304
# Processing chunk 2305
# Processing chunk 2306
# Processing chunk 2307
# Processing chunk 2308
# Processing chunk 2309
# Processing chunk 2310
# Processing chunk 2311
# Processing chunk 2312
# Processing chunk 2313
# Processing chunk 2314
# Processing chunk 2315
# Processing chunk 2316
# Processing chunk 2317
# Processing chunk 2318
# Processing chunk 2319
# Processing chunk 2320
# Processing chunk 2321
# Processing chunk 2322
# Processing chunk 2323
# Processing chunk 2324
# Processing chunk 2325
# Processing chunk 2326
# Processing chunk 2327
# Processing chunk 2328
# Processing chunk 2329
# Processing chunk 2330
# Processing chunk 2331
# Processing chunk 2332
# Processing chunk 2333
# Processing chunk 2334
# Processing chunk 2335
# Processing chunk 2336
# Processing chunk 2337
# Processing chunk 2338
# Processing chunk 2339
# Processing chunk 2340
# Processing chunk 2341
# Processing chunk 2342
# Processing chunk 2343
# Processing chunk 2344
# Processing chunk 2345
# Processing chunk 2346
# Processing chunk 2347
# Processing chunk 2348
# Processing chunk 2349
# Processing chunk 2350
# Processing chunk 2351
# Processing chunk 2352
# Processing chunk 2353
# Processing chunk 2354
# Processing chunk 2355
# Processing chunk 2356
# Processing chunk 2357
# Processing chunk 2358
# Processing chunk 2359
# Processing chunk 2360
# Processing chunk 2361
# Processing chunk 2362
# Processing chunk 2363
# Processing chunk 2364
# Processing chunk 2365
# Processing chunk 2366
# Processing chunk 2367
# Processing chunk 2368
# Processing chunk 2369
# Processing chunk 2370
# Processing chunk 2371
# Processing chunk 2372
# Processing chunk 2373
# Processing chunk 2374
# Processing chunk 2375
# Processing chunk 2376
# Processing chunk 2377
# Processing chunk 2378
# Processing chunk 2379
# Processing chunk 2380
# Processing chunk 2381
# Processing chunk 2382
# Processing chunk 2383
# Processing chunk 2384
# Processing chunk 2385
# Processing chunk 2386
# Processing chunk 2387
# Processing chunk 2388
# Processing chunk 2389
# Processing chunk 2390
# Processing chunk 2391
# Processing chunk 2392
# Processing chunk 2393
# Processing chunk 2394
# Processing chunk 2395
# Processing chunk 2396
# Processing chunk 2397
# Processing chunk 2398
# Processing chunk 2399
# Processing chunk 2400
# Processing chunk 2401
# Processing chunk 2402
# Processing chunk 2403
# Processing chunk 2404
# Processing chunk 2405
# Processing chunk 2406
# Processing chunk 2407
# Processing chunk 2408
# Processing chunk 2409
# Processing chunk 2410
# Processing chunk 2411
# Processing chunk 2412
# Processing chunk 2413
# Processing chunk 2414
# Processing chunk 2415
# Processing chunk 2416
# Processing chunk 2417
# Processing chunk 2418
# Processing chunk 2419
# Processing chunk 2420
# Processing chunk 2421
# Processing chunk 2422
# Processing chunk 2423
# Processing chunk 2424
# Processing chunk 2425
# Processing chunk 2426
# Processing chunk 2427
# Processing chunk 2428
# Processing chunk 2429
# Processing chunk 2430
# Processing chunk 2431
# Processing chunk 2432
# Processing chunk 2433
# Processing chunk 2434
# Processing chunk 2435
# Processing chunk 2436
# Processing chunk 2437
# Processing chunk 2438
# Processing chunk 2439
# Processing chunk 2440
# Processing chunk 2441
# Processing chunk 2442
# Processing chunk 2443
# Processing chunk 2444
# Processing chunk 2445
# Processing chunk 2446
# Processing chunk 2447
# Processing chunk 2448
# Processing chunk 2449
# Processing chunk 2450
# Processing chunk 2451
# Processing chunk 2452
# Processing chunk 2453
# Processing chunk 2454
# Processing chunk 2455
# Processing chunk 2456
# Processing chunk 2457
# Processing chunk 2458
# Processing chunk 2459
# Processing chunk 2460
# Processing chunk 2461
# ✅ Machine-wise 5-min aggregation saved.

# %% [markdown]
# ### Download Machine Events Table

# %%
from google.cloud import storage
import os

client = storage.Client.create_anonymous_client()
bucket = client.bucket("clusterdata-2011-2")

save_dir = r"D:\google_cluster_trace\machine_events"
os.makedirs(save_dir, exist_ok=True)

blob_name = "machine_events/part-00000-of-00001.csv.gz"
dest_file = os.path.join(save_dir, os.path.basename(blob_name))

blob = bucket.blob(blob_name)

if not os.path.exists(dest_file):
    print("Downloading machine_events...")
    blob.download_to_filename(dest_file)
    print("Download complete!")
else:
    print("File already exists.")
# Out:
# Downloading machine_events...
# Download complete!

# %% [markdown]
# ### Preprocessing Machine Events Table

# %%
import os

os.getcwd()
# Out:
# '/Users/madhusudhan/google_data_centre'

# %%
os.listdir()
# Out:
# ['D:\\google_cluster_trace\\machine_5min.csv',
#  '.DS_Store',
#  'D:\\google_cluster_trace\\task_usage',
#  'Untitled.ipynb',
#  'D:\\google_cluster_trace\\task_usage_first8_merged.csv.gz',
#  'D:\\google_cluster_trace\\task_usage_5min_aggregated.csv',
#  '.ipynb_checkpoints',
#  'D:\\google_cluster_trace\\machine_events']

# %%
import os

print(os.path.isdir("D:\\google_cluster_trace\\machine_events"))
print(os.path.isfile("D:\\google_cluster_trace\\machine_events"))
# Out:
# True
# False

# %%
os.listdir("D:\\google_cluster_trace\\machine_events")
# Out:
# ['part-00000-of-00001.csv.gz', 'part-00000-of-00001.csv']

# %%
import os

for root, dirs, files in os.walk("."):
    for f in files:
        if "part-00000" in f:
            print(os.path.join(root, f))
# Out:
# ./D:\google_cluster_trace\task_usage/part-00000-of-00500.csv
# ./D:\google_cluster_trace\machine_events/part-00000-of-00001.csv.gz
# ./D:\google_cluster_trace\machine_events/part-00000-of-00001.csv

# %%
import pandas as pd

file = "./D:\\google_cluster_trace\\machine_events/part-00000-of-00001.csv"

df = pd.read_csv(file, header=None, nrows=1000)

df.columns = [
    "timestamp",
    "machine_id",
    "event_type",
    "platform_id",
    "cpu_capacity",
    "memory_capacity"
]

df
# Out:
#      timestamp  machine_id  event_type  \
# 0            0           5           0
# 1            0           6           0
# 2            0           7           0
# 3            0          10           0
# 4            0          13           0
# ..         ...         ...         ...
# 995          0      908061           0
# 996          0      908063           0
# 997          0      908177           0
# 998          0      908184           0
# 999          0      908187           0
#
#                                       platform_id  cpu_capacity  \
# 0    HofLGzk1Or/8Ildj2+Lqv0UGGvY82NLoni8+J/Yy0RU=           0.5
# 1    HofLGzk1Or/8Ildj2+Lqv0UGGvY82NLoni8+J/Yy0RU=           0.5
# 2    HofLGzk1Or/8Ildj2+Lqv0UGGvY82NLoni8+J/Yy0RU=           0.5
# 3    HofLGzk1Or/8Ildj2+Lqv0UGGvY82NLoni8+J/Yy0RU=           0.5
# 4    HofLGzk1Or/8Ildj2+Lqv0UGGvY82NLoni8+J/Yy0RU=           0.5
# ..                                            ...           ...
# 995  HofLGzk1Or/8Ildj2+Lqv0UGGvY82NLoni8+J/Yy0RU=           0.5
# 996  HofLGzk1Or/8Ildj2+Lqv0UGGvY82NLoni8+J/Yy0RU=           0.5
# 997  HofLGzk1Or/8Ildj2+Lqv0UGGvY82NLoni8+J/Yy0RU=           0.5
# 998  HofLGzk1Or/8Ildj2+Lqv0UGGvY82NLoni8+J/Yy0RU=           0.5
# 999  HofLGzk1Or/8Ildj2+Lqv0UGGvY82NLoni8+J/Yy0RU=           0.5
#
#      memory_capacity
# 0             0.2493
# 1             0.2493
# 2             0.2493
# 3             0.2493
# 4             0.2493
# ..               ...
# 995           0.4995
# 996           0.4995
# 997           0.4995
# 998           0.4995
# 999           0.4995
#
# [1000 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp        1000 non-null   int64
#  1   machine_id       1000 non-null   int64
#  2   event_type       1000 non-null   int64
#  3   platform_id      1000 non-null   object
#  4   cpu_capacity     1000 non-null   float64
#  5   memory_capacity  1000 non-null   float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 47.0+ KB

# %%
df['event_type'].value_counts()
# Out:
# event_type
# 0    1000
# Name: count, dtype: int64

# %%
df['machine_id'].nunique()
df['machine_id'].head()
# Out:
# 0     5
# 1     6
# 2     7
# 3    10
# 4    13
# Name: machine_id, dtype: int64

# %%
df['platform_id'].nunique()
df['platform_id'].value_counts().head()
# Out:
# platform_id
# HofLGzk1Or/8Ildj2+Lqv0UGGvY82NLoni8+J/Yy0RU=    1000
# Name: count, dtype: int64

# %%
df['timestamp'].min()
df['timestamp'].max()
# Out:
# 0

# %%
df['event_type'].unique()
# Out:
# array([0])

# %%
df['event_type'].nunique()
# Out:
# 1

# %%
df['event_type'].value_counts()
# Out:
# event_type
# 0    1000
# Name: count, dtype: int64

# %% [markdown]
# ### Creating Machine wise CSV files

# %%
import pandas as pd
import os

# Load the saved aggregated file
final_df = pd.read_csv(r"D:\google_cluster_trace\machine_5min.csv")

# Now split
output_dir = r"D:\google_cluster_trace\machines_csv"
os.makedirs(output_dir, exist_ok=True)

for machine_id, group in final_df.groupby("machine_id"):
    file_path = os.path.join(output_dir, f"machine_{int(machine_id)}.csv")
    group.to_csv(file_path, index=False)

print("✅ CSV files created.")
# Out:
# ✅ CSV files created.

# %% [markdown]
# ### Downloading Machine Attributes Table

# %%
from google.cloud import storage
import os

client = storage.Client.create_anonymous_client()
bucket = client.bucket("clusterdata-2011-2")

save_dir = r"D:\google_cluster_trace\machine_attributes"
os.makedirs(save_dir, exist_ok=True)

blob_name = "machine_attributes/part-00000-of-00001.csv.gz"
dest_file = os.path.join(save_dir, os.path.basename(blob_name))

blob = bucket.blob(blob_name)

if not os.path.exists(dest_file):
    print("Downloading machine_attributes...")
    blob.download_to_filename(dest_file)
    print("Download complete!")
else:
    print("File already exists.")
# Out:
# Downloading machine_attributes...
# Download complete!

# %%
from google.cloud import storage
import os

client = storage.Client.create_anonymous_client()
bucket = client.bucket("clusterdata-2011-2")

save_dir = r"D:\google_cluster_trace\machine_attributes"
os.makedirs(save_dir, exist_ok=True)

blobs = client.list_blobs(bucket, prefix="machine_attributes/")

for blob in blobs:
    if blob.name.endswith(".csv.gz"):
        dest_file = os.path.join(save_dir, os.path.basename(blob.name))
        
        if not os.path.exists(dest_file):
            print(f"Downloading {blob.name}...")
            blob.download_to_filename(dest_file)

print("✅ All files downloaded.")
# Out:
# ✅ All files downloaded.

# %% [markdown]
# ### Analyze Machine Attribute Table

# %%
import os

dir_path = r"D:\google_cluster_trace\machine_attributes"
files = os.listdir(dir_path)

print(files)
# Out:
# ['.DS_Store', 'part-00000-of-00001.csv.gz', 'part-00000-of-00001.csv']

# %%
import os
print(os.getcwd())
# Out:
# /Users/madhusudhan/google_data_centre

# %%
import os

print(os.listdir())
# Out:
# ['D:\\google_cluster_trace\\machine_attributes', 'D:\\google_cluster_trace\\machine_5min.csv.zip', 'D:\\google_cluster_trace\\machine_5min.csv', '.DS_Store', 'D:\\google_cluster_trace\\task_usage', 'Untitled.ipynb', 'D:\\google_cluster_trace\\machines_csv', 'D:\\google_cluster_trace\\task_usage_first8_merged.csv.gz', 'D:\\google_cluster_trace\\task_usage_5min_aggregated.csv', '.ipynb_checkpoints', 'D:\\google_cluster_trace\\machine_events']

# %%
import os

folder = "D:\\google_cluster_trace\\machine_attributes"
print(os.listdir(folder))
# Out:
# ['.DS_Store', 'part-00000-of-00001.csv.gz', 'part-00000-of-00001.csv']

# %%
import pandas as pd

file = "D:\\google_cluster_trace\\machine_attributes/part-00000-of-00001.csv"

df = pd.read_csv(file, header=None, usecols=[2, 3])
df.columns = ["attribute_name", "attribute_value"]

print(df.head())
print(df.groupby("attribute_name")["attribute_value"].nunique())
# Out:
#                                  attribute_name attribute_value
# 0  +8aLrMrUBQLYLD4Ndxi/ZmwwKGhtFGskL8ZSdChYMdo=               1
# 1  4chZqkETND7f4XrzdWLe8c1eLHKuYgjnUMSV+83EYFA=               1
# 2  5dEuieuWMFy+CNMBBf/uXNX5nP4Kgzeu0O6UizRNK3w=               2
# 3  81Cd14q4ebyI/3TPkkIwGYlB/mvKhBUk3e/E8egb4s0=               2
# 4  9eCGRtl6XN5GQoOYGEjKtupBbtUoOaOPYRFw+pzH7IU=               2
# attribute_name
# +8aLrMrUBQLYLD4Ndxi/ZmwwKGhtFGskL8ZSdChYMdo=      1
# 0xo576GO0NtrJrOsohXyU1rcY2xvi5Tvbus9zY1AzJI=      1
# 3CusDtw4S6+y7vNAxt3TErcLThHzyAXmG7n18SwY1KM=      1
# 4chZqkETND7f4XrzdWLe8c1eLHKuYgjnUMSV+83EYFA=      1
# 5A/UHgbeJPGWK0VQpMLoGVRejsVhhFE57cBUjlOo6gI=      1
#                                                ...
# w3/Je6spb3dt6QfX5PwD2MXqxLTzNur/Ts5JrAwl8xQ=     11
# wNqCDsckjGmkiJStuw+dRMj7oqxTnYssARjPB96ws4Y=      1
# xrLPEfaLoWqEPusv42iPso8MZvlF92N/A3o5pR/IMCQ=    406
# zeTYeXds5XbzYVzUiHe9t3y9K3L5vndxaOFW8btTjU4=      1
# zqEOkdzktGuy9oI7M6oIKxqbyfanRB/pf+3HPNLTSqg=      1
# Name: attribute_value, Length: 67, dtype: int64

# %%
import pandas as pd

file = "D:\\google_cluster_trace\\machine_attributes/part-00000-of-00001.csv"

df = pd.read_csv(file, header=None, usecols=[2])
df.columns = ["attribute_name"]

# count frequency of each attribute_name
counts = df["attribute_name"].value_counts()

print(counts)
# Out:
# attribute_name
# p8ZhzZo6jUe5PdjVklNuNCkogJqCEFA33ZThAAVyqWg=    10128730
# s93lk/yiSwQSBKWr6vfu+qa9xSjEKfQVkl1SEyn3Kow=       39412
# ZpZw+sjJYrnkTFaQa7zK5u8CazfWK8wK8NP496eDlRA=       26908
# 81Cd14q4ebyI/3TPkkIwGYlB/mvKhBUk3e/E8egb4s0=       26050
# iDmVM9CBJbfsTpobqwGRQiSXP2hcCJYwMpY68x9ri9w=       25234
#                                                   ...
# BwF2Hf0IniEL56N9HUmYrefppYb5OLBxuu7u1yGOlmo=         316
# 7obfDY3pItdzskpDqnOvi+oCNJ4lIhlSi42bN7rrK48=         316
# o/0PSEOQ9jWyzNMXehU3dXqePQIE2QxyxyknZMT1k4c=         145
# LKvQbl09pG8btYiBYJWd+pTltGRFZoUHppRdmZqK0EI=          47
# StKUa3Jpf/WqqtUVvj209AVGVQDdyOFFKA0yOKzyFUQ=          16
# Name: count, Length: 67, dtype: int64

# %%
print(counts.head(10))
# Out:
# attribute_name
# p8ZhzZo6jUe5PdjVklNuNCkogJqCEFA33ZThAAVyqWg=    10128730
# s93lk/yiSwQSBKWr6vfu+qa9xSjEKfQVkl1SEyn3Kow=       39412
# ZpZw+sjJYrnkTFaQa7zK5u8CazfWK8wK8NP496eDlRA=       26908
# 81Cd14q4ebyI/3TPkkIwGYlB/mvKhBUk3e/E8egb4s0=       26050
# iDmVM9CBJbfsTpobqwGRQiSXP2hcCJYwMpY68x9ri9w=       25234
# qtu6+42tn0xPmcv0ODnGWRQM0J/SgMM9lNsxc3ckbLw=       25234
# QlHb0NMTSytpaiRqXo9rzLE+wu5f7Cx4uvIm3KZc8lQ=       20237
# Eqr5/diyFWeYBfm508mvBV9y9L8uPjCkYuL1DtgDaSU=       16364
# Mq8KjADLLByyElVUq+c3cFVdXgFEfeCJhw+fKPgWjI4=       13121
# xrLPEfaLoWqEPusv42iPso8MZvlF92N/A3o5pR/IMCQ=       12743
# Name: count, dtype: int64

# %%
import pandas as pd

file = "D:\\google_cluster_trace\\machine_attributes/part-00000-of-00001.csv"

df = pd.read_csv(file, header=None, usecols=[3])
df.columns = ["attribute_value"]

counts = df["attribute_value"].value_counts()

print(counts)
# Out:
# attribute_value
# JXB8WHrJgrUmOCO/cAJjldoh/Eo0jgIdCxVtOloO5tM=    2474465
# 3oaOYSSGfifrdnzKYoZlEDtBBzl7ErG8fqUB72jVxv4=    1885973
# lYF9VCoTJ5FptkBHihIMHZsZKdDKPD3eShXvHLE1aww=     700853
# 9oFWNR7N2j1/NxwsrCFfim2rFZL9bjUe6ZZ5vBeii6U=     612816
# +sJ69cS7gOT30Ow4o5i54UqaO8Tam4SUHVCbw03mad4=     518042
#                                                  ...
# IY3tMXAwZV4myqk2AUtxuL3ZLMl44oZgou4tj16thDA=          1
# sj9IRUZZkl5pBa8Hc4609bY+9Wg35v4n2Wrmxvrh/xg=          1
# 0tEf6j8cf258wtb2XQ8UFS2vemocQPTDuhibeosDqvo=          1
# B5ziOZm9dJ8KKfzmbb80DhbJ8810ckNkzJx+5N/qFqU=          1
# xzSoQS6GOb5SGS+ph0q9sIh4xFMEd20jjycR1CPwzaE=          1
# Name: count, Length: 18011, dtype: int64

# %%
print(counts.head(20))
# Out:
# attribute_value
# JXB8WHrJgrUmOCO/cAJjldoh/Eo0jgIdCxVtOloO5tM=    2474465
# 3oaOYSSGfifrdnzKYoZlEDtBBzl7ErG8fqUB72jVxv4=    1885973
# lYF9VCoTJ5FptkBHihIMHZsZKdDKPD3eShXvHLE1aww=     700853
# 9oFWNR7N2j1/NxwsrCFfim2rFZL9bjUe6ZZ5vBeii6U=     612816
# +sJ69cS7gOT30Ow4o5i54UqaO8Tam4SUHVCbw03mad4=     518042
# b+Sjybrui7jhbh/hi6kOVfaelY75LgkYP9AxCMGN0VA=     454076
# Hl8XVh9Ozi5VOW8HW3sSkocN2O3qqHtohBQ6TolnXzo=     358835
# rYdZofFoBzYtwLRHXUVSUL9KhmgQ/g0QEuNGCri56N4=     327208
# 1                                                204935
# FFCM2qj5F8MmdBgcvfyvhY2izv88oXp4vOWmXw3Zseg=     194331
# dQcbIhtluu0kDC8Ut+4RCMukzfihw8TcIrVXk7TKC00=     193077
# c3jCizIkz+WvNJ3AaoJ6mIKeDSync0TDEkB5x8moGg0=     191883
# 71kVpbt2ly23rAH/I+c3HmJ1Bkm0cn4zm9OUB6QLgr0=     169891
# UT28J9YCXk/PpSnr4kBZ1Mb/a2S2MbXD3xwGEl1Plfs=     163915
# gSNxyfoEyBq74AJ5rUhIufzbf/7bCV1fe73F5Ibn2Ns=     143093
# Bfd8jT1rOqs9aBXEDMkEiHy2LxlKM2QgE2+HJpHuwi0=     119927
# 2                                                114969
# vmK5K8PKF01UcHv9OcoyHVnnoDVu1XYhb6A/9O7GXJk=     109163
# g2vtI/hbmOtS50BiWCd/7Qr3/P6d/s1TVG8sEaCtJrA=      92867
# O73M9pWBiPPLhkknA6zfguqKDh9jGbh0kT3fbrskt9o=      89725
# Name: count, dtype: int64

# %%
import pandas as pd

file = "D:\\google_cluster_trace\\machine_attributes/part-00000-of-00001.csv"

df = pd.read_csv(file, header=None, usecols=[1])
df.columns = ["machine_id"]

print(df["machine_id"].nunique())
# Out:
# 12583

# %%
import pandas as pd

file = "D:\\google_cluster_trace\\machine_attributes/part-00000-of-00001.csv"

df = pd.read_csv(file, header=None, usecols=[2])
df.columns = ["attribute_name"]

print(df["attribute_name"].nunique())
# Out:
# 67

# %%
import pandas as pd

file = "D:\\google_cluster_trace\\machine_attributes/part-00000-of-00001.csv"

df = pd.read_csv(file, header=None, usecols=[1,2])
df.columns = ["machine_id", "attribute_name"]

counts = df.groupby("machine_id")["attribute_name"].nunique()

print(counts.describe())
# Out:
# count    12583.000000
# mean        42.918302
# std          2.399001
# min         40.000000
# 25%         42.000000
# 50%         42.000000
# 75%         43.000000
# max         53.000000
# Name: attribute_name, dtype: float64

# %%
duplicates = df.duplicated(subset=["machine_id", "attribute_name"])

print("Duplicate rows exist:", duplicates.any())
# Out:
# Duplicate rows exist: True

# %%
dup_rows = df[df.duplicated(subset=["machine_id", "attribute_name"], keep=False)]

print(dup_rows.head())
# Out:
#     machine_id                                attribute_name
# 3            5  81Cd14q4ebyI/3TPkkIwGYlB/mvKhBUk3e/E8egb4s0=
# 23           5  ZpZw+sjJYrnkTFaQa7zK5u8CazfWK8wK8NP496eDlRA=
# 26           5  iDmVM9CBJbfsTpobqwGRQiSXP2hcCJYwMpY68x9ri9w=
# 33           5  p8ZhzZo6jUe5PdjVklNuNCkogJqCEFA33ZThAAVyqWg=
# 34           5  qtu6+42tn0xPmcv0ODnGWRQM0J/SgMM9lNsxc3ckbLw=

# %%
counts = df.groupby("machine_id")["attribute_name"].nunique()

print("Min attributes:", counts.min())
print("Max attributes:", counts.max())
# Out:
# Min attributes: 40
# Max attributes: 53

# %%
import pandas as pd

file = "D:\\google_cluster_trace\\machine_attributes/part-00000-of-00001.csv"

df = pd.read_csv(file, header=None, usecols=[0,1,2,3])
df.columns = ["timestamp", "machine_id", "attribute_name", "attribute_value"]

# %%
dup_rows = df[df.duplicated(subset=["machine_id", "attribute_name"], keep=False)]

print(dup_rows.head(50))

# %%
import pandas as pd

file = "D:\\google_cluster_trace\\machine_attributes/part-00000-of-00001.csv"

df = pd.read_csv(file, header=None, usecols=[3])
df.columns = ["attribute_value"]

print(df["attribute_value"].nunique())
# Out:
# 18011

# %% [markdown]
# ### Converting Machines to Clients

# %%
import os

input_dir = r"D:\google_cluster_trace\machines_csv"

files = os.listdir(input_dir)

# extract machine ids from filenames
machine_ids = [int(f.split("_")[1].split(".")[0]) for f in files]

# %%
import random

random.shuffle(machine_ids)

# %%
n_clients = 50

clusters = []
size = len(machine_ids) // n_clients

for i in range(n_clients):
    start = i * size
    end = (i + 1) * size if i != n_clients - 1 else len(machine_ids)
    clusters.append(machine_ids[start:end])

# %%
import json

cluster_dict = {f"client_{i}": clusters[i] for i in range(n_clients)}

with open("clusters.json", "w") as f:
    json.dump(cluster_dict, f)

print("✅ Random clusters created")
# Out:
# ✅ Random clusters created

# %%
output_base = r"D:\google_cluster_trace\clients"

os.makedirs(output_base, exist_ok=True)

for i, machine_list in enumerate(clusters):
    client_dir = os.path.join(output_base, f"client_{i}")
    os.makedirs(client_dir, exist_ok=True)

    for mid in machine_list:
        src = os.path.join(input_dir, f"machine_{mid}.csv")
        dst = os.path.join(client_dir, f"machine_{mid}.csv")
        
        if os.path.exists(src):
            import shutil
            shutil.copy(src, dst)

# %%
import os

input_dir = r"D:\google_cluster_trace\machines_csv"

files = [f for f in os.listdir(input_dir) if f.endswith(".csv")]

# extract machine ids
machine_ids = [int(f.split("_")[1].split(".")[0]) for f in files]

machine_ids.sort()

# 🔥 create 50 clusters
num_clients = 50
clusters = np.array_split(machine_ids, num_clients)

# convert to list of lists
clusters = [list(c) for c in clusters]

print(f"Total clusters created: {len(clusters)}")
print("Example cluster:", clusters[0])
# Out:
# Total clusters created: 50
# Example cluster: [np.int64(5), np.int64(6), np.int64(7), np.int64(10), np.int64(13), np.int64(14), np.int64(19), np.int64(21), np.int64(23), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(36), np.int64(37), np.int64(38), np.int64(39), np.int64(41), np.int64(43), np.int64(45), np.int64(46), np.int64(49), np.int64(52), np.int64(54), np.int64(56), np.int64(60), np.int64(61), np.int64(62), np.int64(63), np.int64(67), np.int64(68), np.int64(72), np.int64(73), np.int64(74), np.int64(75), np.int64(121306), np.int64(243096), np.int64(381113), np.int64(381126), np.int64(381128), np.int64(381129), np.int64(381133), np.int64(381139), np.int64(381227), np.int64(381233), np.int64(381234), np.int64(381235), np.int64(381236), np.int64(381352), np.int64(381361), np.int64(381364), np.int64(381365), np.int64(381368), np.int64(381369), np.int64(381370), np.int64(381371), np.int64(381374), np.int64(381378), np.int64(381381), np.int64(381384), np.int64(381386), np.int64(381389), np.int64(410692), np.int64(410695), np.int64(418535), np.int64(418536), np.int64(418547), np.int64(418548), np.int64(418549), np.int64(418551), np.int64(418552), np.int64(418559), np.int64(418560), np.int64(418561), np.int64(418562), np.int64(418564), np.int64(418565), np.int64(418566), np.int64(418570), np.int64(418572), np.int64(418574), np.int64(418581), np.int64(418583), np.int64(418584), np.int64(418585), np.int64(418586), np.int64(418588), np.int64(418589), np.int64(418689), np.int64(418690), np.int64(418691), np.int64(418695), np.int64(418697), np.int64(418708), np.int64(421565), np.int64(421569), np.int64(421571), np.int64(421574), np.int64(421578), np.int64(421587), np.int64(421592), np.int64(421593), np.int64(422053), np.int64(422055), np.int64(422069), np.int64(422080), np.int64(422082), np.int64(422084), np.int64(422087), np.int64(422090), np.int64(422091), np.int64(450799), np.int64(485231), np.int64(485241), np.int64(486699), np.int64(486702), np.int64(486703), np.int64(486704), np.int64(486707), np.int64(486711), np.int64(486805), np.int64(486816), np.int64(486820), np.int64(486821), np.int64(486826), np.int64(486827), np.int64(486956), np.int64(486957), np.int64(486958), np.int64(486959), np.int64(486961), np.int64(487295), np.int64(487385), np.int64(487386), np.int64(487390), np.int64(487391), np.int64(487397), np.int64(487399), np.int64(487402), np.int64(487403), np.int64(487404), np.int64(487407), np.int64(487411), np.int64(487414), np.int64(487535), np.int64(487538), np.int64(487541), np.int64(487545), np.int64(487547), np.int64(487548), np.int64(495767), np.int64(514995), np.int64(514996), np.int64(567335), np.int64(567336), np.int64(567341), np.int64(567345), np.int64(567348), np.int64(567376), np.int64(567377), np.int64(567382), np.int64(567383), np.int64(567596), np.int64(567597), np.int64(567599), np.int64(567601), np.int64(567604), np.int64(567608), np.int64(567610), np.int64(567611), np.int64(567616), np.int64(567617), np.int64(567618), np.int64(567624), np.int64(567626), np.int64(567748), np.int64(567752), np.int64(567756), np.int64(567757), np.int64(567763), np.int64(567764), np.int64(567769), np.int64(567777), np.int64(567780), np.int64(567782), np.int64(567783), np.int64(567790), np.int64(567902), np.int64(567907), np.int64(567909), np.int64(567910), np.int64(567917), np.int64(567920), np.int64(567924), np.int64(567929), np.int64(567930), np.int64(567933), np.int64(568912), np.int64(595665), np.int64(595666), np.int64(595672), np.int64(595677), np.int64(599601), np.int64(599604), np.int64(599605), np.int64(599607), np.int64(599610), np.int64(599614), np.int64(599619), np.int64(599620), np.int64(599621), np.int64(599623), np.int64(599624), np.int64(599626), np.int64(599632), np.int64(599637), np.int64(599756), np.int64(599757), np.int64(599758), np.int64(599760), np.int64(599763), np.int64(599764), np.int64(599765), np.int64(599770), np.int64(599788), np.int64(599792), np.int64(599793), np.int64(599794), np.int64(602943), np. ...

# %% [markdown]
# ### Client AVG

# %%
import os
import pandas as pd
import numpy as np

output_base = r"D:\google_cluster_trace\clients_avg"
os.makedirs(output_base, exist_ok=True)

for i, machine_list in enumerate(clusters):
    print(f"\nProcessing client {i} | machines: {len(machine_list)}")

    cpu_series_list = []
    mem_series_list = []

    max_len = 0

    # 🔥 LOAD DATA
    for mid in machine_list:
        file_path = os.path.join(input_dir, f"machine_{int(mid)}.csv")

        if not os.path.exists(file_path):
            continue

        try:
            df = pd.read_csv(file_path)

            # 🔍 find CPU & Memory columns
            cpu_cols = [c for c in df.columns if "cpu" in c.lower()]
            mem_cols = [c for c in df.columns if "mem" in c.lower()]

            if not cpu_cols or not mem_cols:
                continue

            cpu = df[cpu_cols[0]].values.astype(float)
            mem = df[mem_cols[0]].values.astype(float)

            cpu_series_list.append(cpu)
            mem_series_list.append(mem)

            max_len = max(max_len, len(cpu))

        except Exception as e:
            print(f"Error reading {mid}: {e}")

    if len(cpu_series_list) == 0:
        print(f"Client {i} skipped (no valid data)")
        continue

    # 🔥 PAD WITH NaN (to keep ALL rows)
    def pad_series(series_list, max_len):
        padded = []
        for s in series_list:
            if len(s) < max_len:
                pad = np.full(max_len - len(s), np.nan)
                s = np.concatenate([s, pad])
            padded.append(s)
        return np.array(padded)

    cpu_aligned = pad_series(cpu_series_list, max_len)
    mem_aligned = pad_series(mem_series_list, max_len)

    print(f"Aligned shape CPU: {cpu_aligned.shape}, MEM: {mem_aligned.shape}")

    # 🔥 AVERAGE (ignore NaN)
    avg_cpu = np.nanmean(cpu_aligned, axis=0)
    avg_mem = np.nanmean(mem_aligned, axis=0)

    # 🔥 SAVE
    out_df = pd.DataFrame({
        "time": np.arange(max_len),
        "cpu_usage": avg_cpu,
        "memory_usage": avg_mem
    })

    out_path = os.path.join(output_base, f"client_{i}.csv")
    out_df.to_csv(out_path, index=False)

    print(f"Saved client_{i}.csv | rows: {max_len}")
# Out:
# Processing client 0 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_0.csv | rows: 8337
#
# Processing client 1 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_1.csv | rows: 8337
#
# Processing client 2 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_2.csv | rows: 8337
#
# Processing client 3 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_3.csv | rows: 8337
#
# Processing client 4 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_4.csv | rows: 8337
#
# Processing client 5 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_5.csv | rows: 8337
#
# Processing client 6 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_6.csv | rows: 8337
#
# Processing client 7 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_7.csv | rows: 8337
#
# Processing client 8 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_8.csv | rows: 8337
#
# Processing client 9 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_9.csv | rows: 8337
#
# Processing client 10 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_10.csv | rows: 8337
#
# Processing client 11 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_11.csv | rows: 8337
#
# Processing client 12 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_12.csv | rows: 8337
#
# Processing client 13 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_13.csv | rows: 8337
#
# Processing client 14 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_14.csv | rows: 8337
#
# Processing client 15 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_15.csv | rows: 8337
#
# Processing client 16 | machines: 252
# Aligned shape CPU: (252, 8336), MEM: (252, 8336)
# Saved client_16.csv | rows: 8336
#
# Processing client 17 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_17.csv | rows: 8337
#
# Processing client 18 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_18.csv | rows: 8337
#
# Processing client 19 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_19.csv | rows: 8337
#
# Processing client 20 | machines: 252
# Aligned shape CPU: (252, 8336), MEM: (252, 8336)
# Saved client_20.csv | rows: 8336
#
# Processing client 21 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_21.csv | rows: 8337
#
# Processing client 22 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_22.csv | rows: 8337
#
# Processing client 23 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_23.csv | rows: 8337
#
# Processing client 24 | machines: 252
# Aligned shape CPU: (252, 8336), MEM: (252, 8336)
# Saved client_24.csv | rows: 8336
#
# Processing client 25 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_25.csv | rows: 8337
#
# Processing client 26 | machines: 252
# Aligned shape CPU: (252, 8336), MEM: (252, 8336)
# Saved client_26.csv | rows: 8336
#
# Processing client 27 | machines: 252
# Aligned shape CPU: (252, 8337), MEM: (252, 8337)
# Saved client_27.csv | rows: 8337
#
# Processing client 28 | machines: 252
# Aligned shape CPU: (252, 8336), MEM: (252, 8336)
# Saved client_28.csv | rows: 8336
#
# Processing client 29 | machines: 252
# Aligned shape CPU: (252, 8336), MEM: (252, 8336)
# Saved client_29.csv | rows: 8336
#
# Processing client 30 | machines: 251
# Aligned shape CPU: (251, 8336), MEM: (251, 8336)
# Saved client_30.csv | rows: 8336
#
# Processing client 31 | machines: 251
# Aligned shape CPU: (251, 8336), MEM: (251, 8336)
# Saved client_31.csv | rows: 8336
#
# Processing client 32 | machines: 251
# Aligned shape CPU: (251, 8336), MEM: (251, 8336)
# Saved client_32.csv | rows: 8336
#
# Processing client 33 | machines: 251
# Aligned shape CPU: (251, 8336), MEM: (251, 8336)
# Saved client_33.csv | rows: 8336
#
# Processing client 34 | machines: 251
# Aligned shape CPU: (251, 8336), MEM: (251, 8336)
# Saved client_34.csv | rows: 8336
#
# Processing client 35 | machines: 251
# Aligned shape CPU: (251, 8337), MEM: (251, 8337)
# Saved client_35.csv | rows: 8337
#
# Processing client 36 | machines: 251
# Aligned shape CPU: (251, 8336), MEM: (251, 8336)
# Saved client_36.csv | rows: 8336
#
# Processing client 37 | machines: 251
# Aligned shape CPU: (251, 8337), MEM: (251, 8337)
# Saved client_37.csv | rows: 8337
#
# Processing client 38 | machines: 251
# Aligned shape CPU: (251, 8336), MEM: (251, 8336)
# Saved client_38.csv | rows: 8336
#
# Processing client 39 | machines: 251
# Aligned shape CPU: (251, 8336), MEM: (251, 8336)
# Saved client_39.csv | rows: 8336
#
# Processing client 40 | machines: 251
# Aligned shape CPU: (251, 8337), MEM: (251, 8337)
# Saved client_40.csv | rows: 8337
#
# Processing client 41 | machines: 251
# Aligned shape CPU: (251, 8337), MEM: (251, 8337)
# Saved client_41.csv | rows: 8337
#
# Processing client 42 | machines: 251
# Aligned shape CPU: (251, 8336), MEM: (251, 8336)
# Saved client_42.csv | rows: 8336
#
# Processing client 43 | machines: 251
# Aligned shape CPU: (251, 8337), MEM: (251, 8337)
# Saved client_43.csv | rows: 8337
#
# Processing client 44 | machines: 251
# Aligned shape CPU: (251, 8336), MEM: (251, 8336)
# Saved client_44.csv | rows: 8336
#
# Processing client 45 | machines: 251
# Aligned shape CPU: (251, 8337), MEM: (251, 8337)
# Saved client_45.csv | rows: 8337
#
# Processing client 46 | machines: 251
# Aligned shape CPU: (251, 8336), MEM: (251, 8336)
# Saved client_46.csv | rows: 8336
#
# Processing client 47 | machines: 251
# Aligned shape CPU: (251, 8337), MEM: (251, 8337)
# Saved client_47.csv | rows: 8337
#
# Processing client 48 | machines: 251
# Aligned shape CPU: (251, 8337), MEM: (251, 8337)
# Saved client_48.csv | rows: 8337
#
# Processing client 49 | machines: 251
# Aligned shape CPU: (251, 8337), MEM: (251, 8337)
# Saved client_49.csv | rows: 8337

# %%
import os
import pandas as pd

input_dir = r"D:\google_cluster_trace\machines_csv"

files = [f for f in os.listdir(input_dir) if f.endswith(".csv")]

print("Total machine files:", len(files))

# Check first 5 machine files
for file in files[:5]:

    path = os.path.join(input_dir, file)

    df = pd.read_csv(path)

    print("\n======================")
    print(file)
    print("======================")

    print("Columns:")
    print(df.columns.tolist())

    print("\nShape:")
    print(df.shape)

    print("\nFirst 5 rows:")
    print(df.head())
# Out:
# Total machine files: 12580
#
# ======================
# machine_765555.csv
# ======================
# Columns:
# ['window', 'machine_id', 'task_count', 'avg_cpu', 'avg_memory']
#
# Shape:
# (8334, 5)
#
# First 5 rows:
#        window  machine_id  task_count   avg_cpu  avg_memory
# 0  6000000000      765555           7  0.031833    0.019721
# 1  6300000000      765555           7  0.031881    0.019130
# 2  6600000000      765555           8  0.026805    0.017193
# 3  6900000000      765555           8  0.037859    0.019005
# 4  7200000000      765555           8  0.046411    0.020439
#
# ======================
# machine_207833106.csv
# ======================
# Columns:
# ['window', 'machine_id', 'task_count', 'avg_cpu', 'avg_memory']
#
# Shape:
# (8330, 5)
#
# First 5 rows:
#        window  machine_id  task_count   avg_cpu  avg_memory
# 0  6000000000   207833106           9  0.024836    0.010684
# 1  6300000000   207833106           8  0.001498    0.002470
# 2  6600000000   207833106           8  0.001892    0.002575
# 3  6900000000   207833106           8  0.002033    0.002608
# 4  7200000000   207833106           9  0.024606    0.010587
#
# ======================
# machine_6565003.csv
# ======================
# Columns:
# ['window', 'machine_id', 'task_count', 'avg_cpu', 'avg_memory']
#
# Shape:
# (8335, 5)
#
# First 5 rows:
#        window  machine_id  task_count   avg_cpu  avg_memory
# 0  5700000000     6565003           7  0.012672    0.028791
# 1  6000000000     6565003          14  0.011093    0.010982
# 2  6300000000     6565003          16  0.011777    0.018007
# 3  6600000000     6565003          15  0.007332    0.009741
# 4  6900000000     6565003          16  0.017520    0.014151
#
# ======================
# machine_1302264.csv
# ======================
# Columns:
# ['window', 'machine_id', 'task_count', 'avg_cpu', 'avg_memory']
#
# Shape:
# (8335, 5)
#
# First 5 rows:
#        window  machine_id  task_count   avg_cpu  avg_memory
# 0  6000000000     1302264          10  0.021673    0.015456
# 1  6300000000     1302264          11  0.018469    0.016655
# 2  6600000000     1302264          10  0.018673    0.014175
# 3  6900000000     1302264          10  0.016866    0.014544
# 4  7200000000     1302264          12  0.021218    0.012350
#
# ======================
# machine_4820074200.csv
# ======================
# Columns:
# ['window', 'machine_id', 'task_count', 'avg_cpu', 'avg_memory']
#
# Shape:
# (8333, 5)
#
# First 5 rows:
#        window  machine_id  task_count   avg_cpu  avg_memory
# 0  6000000000  4820074200          22  0.011747    0.027284
# 1  6300000000  4820074200          22  0.012874    0.027294
# 2  6600000000  4820074200          22  0.012192    0.027370
# 3  6900000000  4820074200          22  0.012314    0.027495
# 4  7200000000  4820074200          22  0.011941    0.027242

# %%
import os
import random
import json
import pandas as pd
from datetime import datetime

# =====================================
# CONFIG
# =====================================

input_dir = r"D:\google_cluster_trace\machines_csv"
output_dir = r"D:\google_cluster_trace\clients_window"

os.makedirs(output_dir, exist_ok=True)

N_CLIENTS = 50

print("="*80)
print("STARTING CLIENT CREATION PIPELINE")
print("="*80)

# =====================================
# GET MACHINE IDS
# =====================================

files = [f for f in os.listdir(input_dir) if f.endswith(".csv")]

machine_ids = [
    int(f.split("_")[1].split(".")[0])
    for f in files
]

print(f"\nTotal machine files found: {len(machine_ids)}")

# =====================================
# RANDOM CLIENT CREATION
# =====================================

random.seed(42)
random.shuffle(machine_ids)

print("\nMachine IDs shuffled successfully")

size = len(machine_ids) // N_CLIENTS

clusters = []

for i in range(N_CLIENTS):

    start = i * size

    if i == N_CLIENTS - 1:
        end = len(machine_ids)
    else:
        end = (i + 1) * size

    clusters.append(machine_ids[start:end])

print(f"Created {len(clusters)} clients")

for i in range(min(5, len(clusters))):
    print(
        f"Client {i}: "
        f"{len(clusters[i])} machines"
    )

# =====================================
# SAVE CLUSTER MAP
# =====================================

cluster_dict = {
    f"client_{i}": clusters[i]
    for i in range(N_CLIENTS)
}

cluster_file = os.path.join(
    output_dir,
    "clusters.json"
)

with open(cluster_file, "w") as f:
    json.dump(cluster_dict, f)

print(f"\nSaved cluster mapping -> {cluster_file}")

# =====================================
# CLIENT DATASET CREATION
# =====================================

for client_idx, machine_list in enumerate(clusters):

    print("\n" + "="*80)
    print(
        f"CLIENT {client_idx}"
        f" | Machines = {len(machine_list)}"
    )
    print("="*80)

    dfs = []

    total_machines = len(machine_list)

    for idx, mid in enumerate(machine_list, start=1):

        file_path = os.path.join(
            input_dir,
            f"machine_{mid}.csv"
        )

        if not os.path.exists(file_path):

            print(
                f"[{idx}/{total_machines}] "
                f"Missing machine_{mid}.csv"
            )
            continue

        try:

            df = pd.read_csv(file_path)

            dfs.append(
                df[
                    [
                        "window",
                        "task_count",
                        "avg_cpu",
                        "avg_memory"
                    ]
                ]
            )

            # print every 25 machines
            if idx % 25 == 0 or idx == total_machines:

                print(
                    f"[{idx}/{total_machines}] "
                    f"Loaded machine_{mid}.csv"
                )

        except Exception as e:

            print(
                f"Error reading machine_{mid}.csv"
            )
            print(e)

    if len(dfs) == 0:

        print(
            f"Client {client_idx} skipped "
            f"(no valid machines)"
        )

        continue

    print(
        f"\nLoaded {len(dfs)} machine files"
    )

    # =====================================
    # CONCATENATE
    # =====================================

    print("Combining machine data...")

    combined = pd.concat(
        dfs,
        ignore_index=True
    )

    print(
        f"Combined rows: {len(combined):,}"
    )

    print(
        f"Unique windows: "
        f"{combined['window'].nunique():,}"
    )

    # =====================================
    # WINDOW-WISE AGGREGATION
    # =====================================

    print(
        "Performing window-wise averaging..."
    )

    client_df = (
        combined
        .groupby("window")
        .agg({
            "task_count": "mean",
            "avg_cpu": "mean",
            "avg_memory": "mean"
        })
        .reset_index()
        .sort_values("window")
    )

    print(
        f"Rows after aggregation: "
        f"{len(client_df):,}"
    )

    # rename

    client_df.rename(
        columns={
            "avg_cpu": "cpu_usage",
            "avg_memory": "memory_usage"
        },
        inplace=True
    )

    print("\nPreview:")

    print(client_df.head())

    # =====================================
    # SAVE
    # =====================================

    output_file = os.path.join(
        output_dir,
        f"client_{client_idx}.csv"
    )

    client_df.to_csv(
        output_file,
        index=False
    )

    print(
        f"\nSaved -> {output_file}"
    )

    print(
        f"Final shape: {client_df.shape}"
    )

print("\n" + "="*80)
print("ALL CLIENTS CREATED SUCCESSFULLY")
print("="*80)
# Out:
# ================================================================================
# STARTING CLIENT CREATION PIPELINE
# ================================================================================
#
# Total machine files found: 12580
#
# Machine IDs shuffled successfully
# Created 50 clients
# Client 0: 251 machines
# Client 1: 251 machines
# Client 2: 251 machines
# Client 3: 251 machines
# Client 4: 251 machines
#
# Saved cluster mapping -> D:\google_cluster_trace\clients_window/clusters.json
#
# ================================================================================
# CLIENT 0 | Machines = 251
# ================================================================================
# [25/251] Loaded machine_3346111386.csv
# [50/251] Loaded machine_4820318859.csv
# [75/251] Loaded machine_904468.csv
# [100/251] Loaded machine_317495581.csv
# [125/251] Loaded machine_644879424.csv
# [150/251] Loaded machine_336055581.csv
# [175/251] Loaded machine_38646844.csv
# [200/251] Loaded machine_17504055.csv
# [225/251] Loaded machine_1760950962.csv
# [250/251] Loaded machine_2787328289.csv
# [251/251] Loaded machine_257336997.csv
#
# Loaded 251 machine files
# Combining machine data...
# Combined rows: 2,066,192
# Unique windows: 8,337
# Performing window-wise averaging...
# Rows after aggregation: 8,337
#
# Preview:
#        window  task_count  cpu_usage  memory_usage
# 0  5400000000    3.000000   0.000419      0.000066
# 1  5700000000    1.468354   0.011383      0.007912
# 2  6000000000   10.638554   0.016678      0.021135
# 3  6300000000   10.951807   0.016374      0.021033
# 4  6600000000   10.634538   0.015862      0.021303
#
# Saved -> D:\google_cluster_trace\clients_window/client_0.csv
# Final shape: (8337, 4)
#
# ================================================================================
# CLIENT 1 | Machines = 251
# ================================================================================
# [25/251] Loaded machine_
# Unique windows: 8,337
# Performing window-wise averaging...
# Rows after aggregation: 8,337
#
# Preview:
#        window  task_count  cpu_usage  memory_usage
# 0  5400000000    3.333333   0.006581      0.005366
# 1  5700000000    1.587500   0.016742      0.010893
# 2  6000000000   11.068548   0.016807      0.021879
# 3  6300000000   11.391129   0.016053      0.021126
# 4  6600000000   10.866935   0.016311      0.021858
#
# Saved -> D:\google_cluster_trace\clients_window/client_48.csv
# Final shape: (8337, 4)
#
# ================================================================================
# CLIENT 49 | Machines = 281
# ================================================================================
# [25/281] Loaded machine_4820211120.csv
# [50/281] Loaded machine_1436387371.csv
# [75/281] Loaded machine_38751130.csv
# [100/281] Loaded machine_258762301.csv
# [125/281] Loaded machine_2823481911.csv
# [150/281] Loaded machine_424231417.csv
# [175/281] Loaded machine_336058857.csv
# [200/281] Loaded machine_7314116.csv
# [225/281] Loaded machine_1436530091.csv
# [250/281] Loaded machine_491792395.csv
# [275/281] Loaded machine_257495887.csv
# [281/281] Loaded machine_336055580.csv
#
# Loaded 281 machine files
# Combining machine data...
# Combined rows: 2,328,992
# Unique windows: 8,337
# Performing window-wise averaging...
# Rows after aggregation: 8,337
#
# Preview:
#        window  task_count  cpu_usage  memory_usage
# 0  5400000000    2.333333   0.000448      0.000021
# 1  5700000000    1.636364   0.012612      0.009775
# 2  6000000000   11.187050   0.016275      0.020776
# 3  6300000000   11.467626   0.015504      0.020353
# 4  6600000000   11.136691   0.015790      0.020931
#
# Saved -> D:\google_cluster_trace\clients_window/client_49.csv
# Final shape: (8337, 4)
#
# ================================================================================
# ALL CLIENTS CREATED SUCCESSFULLY
# ================================================================================

# %%
# ================== IMPORTS ==================
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import random

# %% [markdown]
# ### LSTM-Attention Model Architecture

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size=11, hidden_size=128, dropout=0.3):
        super().__init__()

        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=2,
            batch_first=True,
            dropout=dropout
        )

        self.attn = nn.Linear(hidden_size, 1)

        self.fc1 = nn.Linear(hidden_size, 32)

        self.relu = nn.ReLU()

        self.dropout = nn.Dropout(dropout)

        self.fc2 = nn.Linear(32, 2)

    def forward(self, x):

        out, _ = self.lstm(x)

        attn_weights = torch.softmax(
            self.attn(out),
            dim=1
        )

        context = torch.sum(
            attn_weights * out,
            dim=1
        )

        out = self.fc1(context)

        out = self.relu(out)

        out = self.dropout(out)

        return self.fc2(out)

# %% [markdown]
# ### Data Loading, Feature Engineering & Normalization

# %%
def load_split_normalize(file_path, window_size):

    print(f"\nLoading {os.path.basename(file_path)}")

    df = pd.read_csv(file_path)

    print("Original Shape:", df.shape)

    task = df["task_count"].values.astype(float)
    cpu = df["cpu_usage"].values.astype(float)
    mem = df["memory_usage"].values.astype(float)

    df = pd.DataFrame({

        "task": task,
        "cpu": cpu,
        "mem": mem

    })

    # ==========================
    # TASK FEATURES
    # ==========================

    df["task_diff"] = df["task"].diff()

    df["task_ma_3"] = (
        df["task"]
        .rolling(3)
        .mean()
    )

    # ==========================
    # CPU FEATURES
    # ==========================

    df["cpu_diff"] = df["cpu"].diff()

    df["cpu_ma_3"] = (
        df["cpu"]
        .rolling(3)
        .mean()
    )

    # ==========================
    # MEMORY FEATURES
    # ==========================

    df["mem_diff"] = df["mem"].diff()

    df["mem_ma_3"] = (
        df["mem"]
        .rolling(3)
        .mean()
    )

    # ==========================
    # SPIKES
    # ==========================

    df["cpu_spike"] = (
        df["cpu_diff"] >
        df["cpu_diff"].std()
    ).astype(int)

    df["mem_spike"] = (
        df["mem_diff"] >
        df["mem_diff"].std()
    ).astype(int)

    df = df.dropna()

    print(
        "Shape After Feature Engineering:",
        df.shape
    )

    data = df.values

    if len(data) < window_size + 1:

        print(
            "Skipped: Not enough rows"
        )

        return None

    split = int(
        0.8 * len(data)
    )

    train_data = data[:split]

    test_data = data[split:]

    mean = train_data.mean(axis=0)

    std = (
        train_data.std(axis=0)
        + 1e-6
    )

    train_data = (
        train_data - mean
    ) / std

    test_data = (
        test_data - mean
    ) / std

    print(
        "Train Shape:",
        train_data.shape
    )

    print(
        "Test Shape:",
        test_data.shape
    )

    return (
        train_data,
        test_data,
        mean,
        std
    )

# %% [markdown]
# ### Sequence Generation for Time-Series Forecasting

# %%
def create_sequences(data, window_size):
    X, y = [], []

    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size][:2])  # 🔥 CPU + MEMORY

    return np.array(X), np.array(y)

# %%
def compute_metrics(y_true, y_pred):
    y_pred = y_pred

    mse = np.mean((y_true - y_pred) ** 2, axis=0)
    mae = np.mean(np.abs(y_true - y_pred), axis=0)
    rmse = np.sqrt(mse)

    return mse, mae, rmse

# %% [markdown]
# ### Local Client Model Training

# %%
def train_local(model, X, y, epochs=15, batch_size=32):
    model.train()

    optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)
    loss_fn = nn.HuberLoss(delta=1.0)

    X_tensor = torch.tensor(X, dtype=torch.float32)
    y_tensor = torch.tensor(y, dtype=torch.float32)

    dataset = torch.utils.data.TensorDataset(X_tensor, y_tensor)
    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

    total_loss, count = 0, 0

    for _ in range(epochs):
        for batch_X, batch_y in loader:
            optimizer.zero_grad()

            pred = model(batch_X)
            loss = loss_fn(pred, batch_y)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * batch_X.size(0)
            count += batch_X.size(0)

    return model.state_dict(), total_loss / count

# %% [markdown]
# ### Aquila Optimizer for Adaptive Weight Selection

# %%
def aquila_optimizer(losses, pop_size=10, iters=30):
    losses = np.array(losses)
    n = len(losses)

    # Normalize losses (important)
    losses = losses / (np.max(losses) + 1e-8)

    # Initialize population (valid probability vectors)
    pop = np.random.rand(pop_size, n)
    pop = pop / pop.sum(axis=1, keepdims=True)

    best = pop[0].copy()
    best_fit = float("inf")

    lambda_reg = 0.1  # regularization to avoid collapse

    for t in range(iters):

        for i in range(pop_size):
            alpha = pop[i]

            # Fitness function (minimize weighted loss + smoothness)
            fitness = np.sum(alpha * losses) + lambda_reg * np.sum(alpha**2)

            if fitness < best_fit:
                best_fit = fitness
                best = alpha.copy()

        # -------- Aquila Update Phases --------
        for i in range(pop_size):

            r1 = np.random.rand(n)
            r2 = np.random.rand(n)

            if t < iters / 2:
                # Exploration phase
                pop[i] = pop[i] + 0.5 * (r1 - r2)
            else:
                # Exploitation phase (move toward best)
                pop[i] = pop[i] + 0.5 * (best - pop[i]) + 0.1 * (r1 - r2)

            # Keep weights valid
            pop[i] = np.clip(pop[i], 1e-6, None)
            pop[i] = pop[i] / pop[i].sum()

    # Final smoothing (VERY IMPORTANT)
    temperature = 0.5
    best = np.exp(best / temperature)
    best = best / best.sum()

    return best

# %%
def aggregate_aquila(
    global_model,
    local_weights,
    losses
):

    print("\nRunning Aquila Optimizer...")

    alphas = aquila_optimizer(
        losses
    )

    print(
        "Client Losses:",
        np.round(losses, 6)
    )

    print(
        "Aggregation Weights:",
        np.round(alphas, 4)
    )

    new_weights = {}

    for key in global_model.state_dict():

        new_weights[key] = sum(

            local_weights[i][key]
            * alphas[i]

            for i in range(
                len(local_weights)
            )

        )

    global_model.load_state_dict(
        new_weights
    )

    return global_model

# %% [markdown]
# ### Federated Learning

# %%
def federated_training(
    base_path,
    rounds=10,
    window_size=30
):

    client_files = [

        os.path.join(
            base_path,
            f
        )

        for f in os.listdir(base_path)

        if f.endswith(".csv")
    ]

    print("\n" + "="*60)
    print("FEDERATED TRAINING STARTED")
    print("="*60)

    print(
        f"Total Clients Found: "
        f"{len(client_files)}"
    )

    global_model = LSTMModel()

    selected_client_names = [
    "client_25.csv",
    "client_14.csv",
    "client_17.csv",
    "client_32.csv",
    "client_36.csv"
    ]

    selected_clients = [
     os.path.join(base_path, client)
     for client in selected_client_names
    ]

    print("\nSelected Clients:")

    for i, c in enumerate(
        selected_clients
    ):

        print(
            f"{i+1}. "
            f"{os.path.basename(c)}"
        )

    all_mse = []
    all_rmse = []

    client_predictions = {}

    for r in range(rounds):

        print(
            "\n" + "="*60
        )

        print(
            f"ROUND {r+1}"
        )

        print(
            "="*60
        )

        local_weights = []
        losses = []

        round_mse = []
        round_rmse = []

        for file in selected_clients:

            result = load_split_normalize(
                file,
                window_size
            )

            if result is None:
                continue

            (
                train_data,
                test_data,
                mean,
                std
            ) = result

            X_train, y_train = (
                create_sequences(
                    train_data,
                    window_size
                )
            )

            X_test, y_test = (
                create_sequences(
                    test_data,
                    window_size
                )
            )

            print(
                f"\n{os.path.basename(file)}"
            )

            print(
                "Train Sequences:",
                X_train.shape
            )

            print(
                "Test Sequences:",
                X_test.shape
            )

            if (
                len(X_train) == 0
                or
                len(X_test) == 0
            ):
                continue

            local_model = LSTMModel()

            local_model.load_state_dict(
                global_model.state_dict()
            )

            weights, train_loss = train_local(
                local_model,
                X_train,
                y_train
            )

            print(
                f"Train Loss: "
                f"{train_loss:.6f}"
            )

            local_model.eval()

            with torch.no_grad():

                preds = local_model(

                    torch.tensor(
                        X_test,
                        dtype=torch.float32
                    )

                ).numpy()

            # =====================
            # DENORMALIZATION
            # =====================

            preds[:,0] = (
                preds[:,0]
                * std[1]
                + mean[1]
            )

            preds[:,1] = (
                preds[:,1]
                * std[2]
                + mean[2]
            )

            y_test[:,0] = (
                y_test[:,0]
                * std[1]
                + mean[1]
            )

            y_test[:,1] = (
                y_test[:,1]
                * std[2]
                + mean[2]
            )

            mse, mae, rmse = (
                compute_metrics(
                    y_test,
                    preds
                )
            )

            print(
                f"CPU MSE : {mse[0]:.8f}"
            )

            print(
                f"CPU RMSE: {rmse[0]:.8f}"
            )

            print(
                f"MEM MSE : {mse[1]:.8f}"
            )

            print(
                f"MEM RMSE: {rmse[1]:.8f}"
            )

            client_predictions[
                os.path.basename(file)
            ] = {

                "y_true": y_test,

                "y_pred": preds

            }

            local_weights.append(
                weights
            )

            losses.append(
                np.mean(rmse)
            )

            round_mse.append(
                np.mean(mse)
            )

            round_rmse.append(
                np.mean(rmse)
            )

        if not local_weights:
            continue

        avg_mse = np.mean(
            round_mse
        )

        avg_rmse = np.mean(
            round_rmse
        )

        print(
            "\nROUND SUMMARY"
        )

        print(
            f"MSE  : {avg_mse:.8f}"
        )

        print(
            f"RMSE : {avg_rmse:.8f}"
        )

        all_mse.append(
            avg_mse
        )

        all_rmse.append(
            avg_rmse
        )

        global_model = (
            aggregate_aquila(
                global_model,
                local_weights,
                losses
            )
        )

    print("\nTraining Completed")

    return (
        global_model,
        all_mse,
        all_rmse,
        client_predictions
    )

# %%
base_path = r"D:\google_cluster_trace\clients_window"

model, mse_list, rmse_list, client_preds = federated_training(
    base_path=base_path,
    rounds=10,
    window_size=30
)
# Out:
# ============================================================
# FEDERATED TRAINING STARTED
# ============================================================
# Total Clients Found: 50
#
# Selected Clients:
# 1. client_25.csv
# 2. client_14.csv
# 3. client_17.csv
# 4. client_32.csv
# 5. client_36.csv
#
# ============================================================
# ROUND 1
# ============================================================
#
# Loading client_25.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_25.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.101151
# CPU MSE : 0.00000424
# CPU RMSE: 0.00205914
# MEM MSE : 0.00000121
# MEM RMSE: 0.00110185
#
# Loading client_14.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_14.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.104530
# CPU MSE : 0.00000369
# CPU RMSE: 0.00192204
# MEM MSE : 0.00000110
# MEM RMSE: 0.00104978
#
# Loading client_17.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_17.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.101082
# CPU MSE : 0.00000388
# CPU RMSE: 0.00196913
# MEM MSE : 0.00000104
# MEM RMSE: 0.00102028
#
# Loading client_32.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_32.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.105189
# CPU MSE : 0.00000355
# CPU RMSE: 0.00188325
# MEM MSE : 0.00000134
# MEM RMSE: 0.00115848
#
# Loading client_36.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_36.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.101142
# CPU MSE : 0.00000404
# CPU RMSE: 0.00200984
# MEM MSE : 0.00000135
# MEM RMSE: 0.00116114
#
# ROUND SUMMARY
# MSE  : 0.00000254
# RMSE : 0.00153349
#
# Running Aquila Optimizer...
# Client Losses: [0.00158  0.001486 0.001495 0.001521 0.001585]
# Aggregation Weights: [0.14   0.2549 0.2497 0.2116 0.1438]
#
# ============================================================
# ROUND 2
# ============================================================
#
# Loading client_25.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_25.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.083875
# CPU MSE : 0.00000433
# CPU RMSE: 0.00208007
# MEM MSE : 0.00000125
# MEM RMSE: 0.00111588
#
# Loading client_14.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_14.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.085903
# CPU MSE : 0.00000365
# CPU RMSE: 0.00191174
# MEM MSE : 0.00000113
# MEM RMSE: 0.00106257
#
# Loading client_17.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_17.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.081717
# CPU MSE : 0.00000392
# CPU RMSE: 0.00197988
# MEM MSE : 0.00000103
# MEM RMSE: 0.00101727
#
# Loading client_32.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_32.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.085150
# CPU MSE : 0.00000356
# CPU RMSE: 0.00188572
# MEM MSE : 0.00000138
# MEM RMSE: 0.00117304
#
# Loading client_36.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_36.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.082290
# CPU MSE : 0.00000403
# CPU RMSE: 0.00200797
# MEM MSE : 0.00000138
# MEM RMSE: 0.00117631
#
# ROUND SUMMARY
# MSE  : 0.00000257
# RMSE : 0.00154104
#
# Running Aquila Optimizer...
# Client Losses: [0.001598 0.001487 0.001499 0.001529 0.001592]
# Aggregation Weights: [0.1284 0.2728 0.2508 0.204  0.1441]
#
# ============================================================
# ROUND 3
# ============================================================
#
# Loading client_25.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_25.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.080253
# CPU MSE : 0.00000450
# CPU RMSE: 0.00212022
# MEM MSE : 0.00000131
# MEM RMSE: 0.00114292
#
# Loading client_14.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_14.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.082296
# CPU MSE : 0.00000379
# CPU RMSE: 0.00194570
# MEM MSE : 0.00000119
# MEM RMSE: 0.00108957
#
# Loading client_17.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_17.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.078257
# CPU MSE : 0.00000406
# CPU RMSE: 0.00201482
# MEM MSE : 0.00000108
# MEM RMSE: 0.00104080
#
# Loading client_32.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_32.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.080417
# CPU MSE : 0.00000368
# CPU RMSE: 0.00191845
# MEM MSE : 0.00000135
# MEM RMSE: 0.00116323
#
# Loading client_36.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_36.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.078465
# CPU MSE : 0.00000419
# CPU RMSE: 0.00204594
# MEM MSE : 0.00000133
# MEM RMSE: 0.00115352
#
# ROUND SUMMARY
# MSE  : 0.00000265
# RMSE : 0.00156352
#
# Running Aquila Optimizer...
# Client Losses: [0.001632 0.001518 0.001528 0.001541 0.0016  ]
# Aggregation Weights: [0.1296 0.2539 0.2407 0.2216 0.1541]
#
# ============================================================
# ROUND 4
# ============================================================
#
# Loading client_25.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_25.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.076326
# CPU MSE : 0.00000445
# CPU RMSE: 0.00210861
# MEM MSE : 0.00000121
# MEM RMSE: 0.00109798
#
# Loading client_14.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_14.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.078374
# CPU MSE : 0.00000385
# CPU RMSE: 0.00196324
# MEM MSE : 0.00000118
# MEM RMSE: 0.00108853
#
# Loading client_17.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_17.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.074921
# CPU MSE : 0.00000418
# CPU RMSE: 0.00204544
# MEM MSE : 0.00000110
# MEM RMSE: 0.00104829
#
# Loading client_32.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_32.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.077535
# CPU MSE : 0.00000392
# CPU RMSE: 0.00197886
# MEM MSE : 0.00000151
# MEM RMSE: 0.00122739
#
# Loading client_36.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_36.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.075076
# CPU MSE : 0.00000418
# CPU RMSE: 0.00204551
# MEM MSE : 0.00000139
# MEM RMSE: 0.00117750
#
# ROUND SUMMARY
# MSE  : 0.00000270
# RMSE : 0.00157814
#
# Running Aquila Optimizer...
# Client Losses: [0.001603 0.001526 0.001547 0.001603 0.001612]
# Aggregation Weights: [0.1631 0.2721 0.2517 0.1612 0.1521]
#
# ============================================================
# ROUND 5
# ============================================================
#
# Loading client_25.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_25.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.072857
# CPU MSE : 0.00000477
# CPU RMSE: 0.00218294
# MEM MSE : 0.00000130
# MEM RMSE: 0.00113846
#
# Loading client_14.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_14.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.074587
# CPU MSE : 0.00000387
# CPU RMSE: 0.00196777
# MEM MSE : 0.00000126
# MEM RMSE: 0.00112192
#
# Loading client_17.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_17.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.071524
# CPU MSE : 0.00000429
# CPU RMSE: 0.00207222
# MEM MSE : 0.00000121
# MEM RMSE: 0.00110111
#
# Loading client_32.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_32.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.073784
# CPU MSE : 0.00000385
# CPU RMSE: 0.00196278
# MEM MSE : 0.00000135
# MEM RMSE: 0.00116209
#
# Loading client_36.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_36.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.071578
# CPU MSE : 0.00000424
# CPU RMSE: 0.00205923
# MEM MSE : 0.00000143
# MEM RMSE: 0.00119734
#
# ROUND SUMMARY
# MSE  : 0.00000276
# RMSE : 0.00159659
#
# Running Aquila Optimizer...
# Client Losses: [0.001661 0.001545 0.001587 0.001562 0.001628]
# Aggregation Weights: [0.132  0.2666 0.202  0.2352 0.1642]
#
# ============================================================
# ROUND 6
# ============================================================
#
# Loading client_25.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_25.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.069433
# CPU MSE : 0.00000455
# CPU RMSE: 0.00213269
# MEM MSE : 0.00000135
# MEM RMSE: 0.00116263
#
# Loading client_14.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_14.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.071327
# CPU MSE : 0.00000409
# CPU RMSE: 0.00202151
# MEM MSE : 0.00000131
# MEM RMSE: 0.00114433
#
# Loading client_17.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_17.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.068006
# CPU MSE : 0.00000434
# CPU RMSE: 0.00208270
# MEM MSE : 0.00000123
# MEM RMSE: 0.00110977
#
# Loading client_32.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_32.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.070414
# CPU MSE : 0.00000420
# CPU RMSE: 0.00204993
# MEM MSE : 0.00000147
# MEM RMSE: 0.00121142
#
# Loading client_36.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_36.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.068256
# CPU MSE : 0.00000429
# CPU RMSE: 0.00207241
# MEM MSE : 0.00000157
# MEM RMSE: 0.00125436
#
# ROUND SUMMARY
# MSE  : 0.00000284
# RMSE : 0.00162418
#
# Running Aquila Optimizer...
# Client Losses: [0.001648 0.001583 0.001596 0.001631 0.001663]
# Aggregation Weights: [0.1764 0.2505 0.227  0.1968 0.1492]
#
# ============================================================
# ROUND 7
# ============================================================
#
# Loading client_25.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_25.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.065368
# CPU MSE : 0.00000469
# CPU RMSE: 0.00216472
# MEM MSE : 0.00000142
# MEM RMSE: 0.00119097
#
# Loading client_14.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_14.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.067332
# CPU MSE : 0.00000408
# CPU RMSE: 0.00202114
# MEM MSE : 0.00000139
# MEM RMSE: 0.00117895
#
# Loading client_17.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_17.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.064105
# CPU MSE : 0.00000443
# CPU RMSE: 0.00210380
# MEM MSE : 0.00000127
# MEM RMSE: 0.00112714
#
# Loading client_32.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_32.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.066225
# CPU MSE : 0.00000451
# CPU RMSE: 0.00212252
# MEM MSE : 0.00000152
# MEM RMSE: 0.00123161
#
# Loading client_36.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_36.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.064669
# CPU MSE : 0.00000447
# CPU RMSE: 0.00211504
# MEM MSE : 0.00000157
# MEM RMSE: 0.00125407
#
# ROUND SUMMARY
# MSE  : 0.00000293
# RMSE : 0.00165100
#
# Running Aquila Optimizer...
# Client Losses: [0.001678 0.0016   0.001615 0.001677 0.001685]
# Aggregation Weights: [0.1687 0.2718 0.2252 0.173  0.1613]
#
# ============================================================
# ROUND 8
# ============================================================
#
# Loading client_25.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_25.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.061783
# CPU MSE : 0.00000492
# CPU RMSE: 0.00221703
# MEM MSE : 0.00000141
# MEM RMSE: 0.00118784
#
# Loading client_14.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_14.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.062734
# CPU MSE : 0.00000427
# CPU RMSE: 0.00206690
# MEM MSE : 0.00000156
# MEM RMSE: 0.00124980
#
# Loading client_17.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_17.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.060204
# CPU MSE : 0.00000464
# CPU RMSE: 0.00215469
# MEM MSE : 0.00000147
# MEM RMSE: 0.00121243
#
# Loading client_32.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_32.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.062215
# CPU MSE : 0.00000443
# CPU RMSE: 0.00210571
# MEM MSE : 0.00000156
# MEM RMSE: 0.00124921
#
# Loading client_36.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_36.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.060999
# CPU MSE : 0.00000448
# CPU RMSE: 0.00211693
# MEM MSE : 0.00000167
# MEM RMSE: 0.00129126
#
# ROUND SUMMARY
# MSE  : 0.00000304
# RMSE : 0.00168518
#
# Running Aquila Optimizer...
# Client Losses: [0.001702 0.001658 0.001684 0.001677 0.001704]
# Aggregation Weights: [0.1842 0.2376 0.2016 0.2017 0.1748]
#
# ============================================================
# ROUND 9
# ============================================================
#
# Loading client_25.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_25.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.058986
# CPU MSE : 0.00000495
# CPU RMSE: 0.00222552
# MEM MSE : 0.00000139
# MEM RMSE: 0.00118082
#
# Loading client_14.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_14.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.058910
# CPU MSE : 0.00000443
# CPU RMSE: 0.00210411
# MEM MSE : 0.00000146
# MEM RMSE: 0.00120754
#
# Loading client_17.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_17.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.056445
# CPU MSE : 0.00000473
# CPU RMSE: 0.00217547
# MEM MSE : 0.00000145
# MEM RMSE: 0.00120602
#
# Loading client_32.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_32.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.058643
# CPU MSE : 0.00000450
# CPU RMSE: 0.00212142
# MEM MSE : 0.00000163
# MEM RMSE: 0.00127701
#
# Loading client_36.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_36.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.056926
# CPU MSE : 0.00000461
# CPU RMSE: 0.00214758
# MEM MSE : 0.00000176
# MEM RMSE: 0.00132658
#
# ROUND SUMMARY
# MSE  : 0.00000309
# RMSE : 0.00169721
#
# Running Aquila Optimizer...
# Client Losses: [0.001703 0.001656 0.001691 0.001699 0.001737]
# Aggregation Weights: [0.1886 0.2484 0.206  0.1974 0.1595]
#
# ============================================================
# ROUND 10
# ============================================================
#
# Loading client_25.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_25.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.054363
# CPU MSE : 0.00000501
# CPU RMSE: 0.00223924
# MEM MSE : 0.00000153
# MEM RMSE: 0.00123730
#
# Loading client_14.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_14.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.055242
# CPU MSE : 0.00000456
# CPU RMSE: 0.00213552
# MEM MSE : 0.00000154
# MEM RMSE: 0.00123987
#
# Loading client_17.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_17.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.053196
# CPU MSE : 0.00000478
# CPU RMSE: 0.00218688
# MEM MSE : 0.00000146
# MEM RMSE: 0.00120635
#
# Loading client_32.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_32.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.055274
# CPU MSE : 0.00000436
# CPU RMSE: 0.00208781
# MEM MSE : 0.00000163
# MEM RMSE: 0.00127705
#
# Loading client_36.csv
# Original Shape: (8337, 4)
# Shape After Feature Engineering: (8335, 11)
# Train Shape: (6668, 11)
# Test Shape: (1667, 11)
#
# client_36.csv
# Train Sequences: (6638, 30, 11)
# Test Sequences: (1637, 30, 11)
# Train Loss: 0.054048
# CPU MSE : 0.00000464
# CPU RMSE: 0.00215470
# MEM MSE : 0.00000175
# MEM RMSE: 0.00132152
#
# ROUND SUMMARY
# MSE  : 0.00000313
# RMSE : 0.00170862
#
# Running Aquila Optimizer...
# Client Losses: [0.001738 0.001688 0.001697 0.001682 0.001738]
# Aggregation Weights: [0.1651 0.2205 0.2162 0.2295 0.1686]
#
# Training Completed

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
rounds = range(1, len(mse_list) + 1)

plt.figure()
plt.plot(rounds, mse_list, label="MSE")
plt.plot(rounds, rmse_list, label="RMSE")

plt.xlabel("Rounds")
plt.ylabel("Error")
plt.title("Federated Training Performance")
plt.legend()
plt.grid()

plt.show()
for client, data in client_preds.items():

    y_true = data["y_true"]
    y_pred = data["y_pred"]

    # CPU
    plt.figure()
    plt.plot(y_true[:200, 0], label="CPU True")
    plt.plot(y_pred[:200, 0], label="CPU Pred")

    plt.title(f"{client} → CPU Prediction")
    plt.xlabel("Time")
    plt.ylabel("CPU Usage")
    plt.legend()
    plt.grid()
    plt.show()

    # MEMORY
    plt.figure()
    plt.plot(y_true[:200, 1], label="Memory True")
    plt.plot(y_pred[:200, 1], label="Memory Pred")

    plt.title(f"{client} → Memory Prediction")
    plt.xlabel("Time")
    plt.ylabel("Memory Usage")
    plt.legend()
    plt.grid()
    plt.show()
